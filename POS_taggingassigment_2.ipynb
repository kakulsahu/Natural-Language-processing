# %% [markdown]
# # **Implement POS tagging on a text corpus using an NLP library (like NLTK or SpaCy). Analyze the grammatical structure of sentences using syntactic/dependency parsing.**

# %%
import spacy

# %%
nlp = spacy.load("en_core_web_sm")

# %%
text = """
"en.wikipedia.org" redirects here. For the main page, see Main Page. For the version of Wikipedia written in Basic English, see Simple English Wikipedia.
Favicon of Wikipedia English Wikipedia
Wikipedia logo with text: WIKIPEDIA The Free Encyclopedia
Screenshot
Type of site	Online encyclopedia
Available in	English
Owner	Wikimedia Foundation
Founder(s)	Jimmy Wales
Larry Sanger
Editors	English Wikipedia community
URL	en.wikipedia.org Edit this at Wikidata
Commercial	No
Registration	Optional; required for certain tasks
Users	50.7 million (as of 19 December 2025)
Launched	15 January 2001; 24 years ago
Content license	Creative Commons Attribution/
Share-Alike 4.0 (most text also dual-licensed under GFDL)
Media licensing varies
Written in	PHP
The English Wikipedia is the primary[a] English-language edition of Wikipedia, an online encyclopedia. It was created by Jimmy Wales and Larry Sanger on 15 January 2001, as Wikipedia's first edition.

English Wikipedia is hosted alongside other language editions by the Wikimedia Foundation, an American nonprofit organization. Its content, written independently of other editions by volunteer editors known as Wikipedians,[1] is in various varieties of English while aiming to stay consistent within articles. Its internal newspaper is The Signpost.

English Wikipedia is the most read version of Wikipedia,[2][3] accounting for 48% of Wikipedia's cumulative traffic, with the remaining percentage split among the other languages.[4] The English Wikipedia has the most articles of any edition, at 7,107,928 as of December 2025.[b] It contains 10.8% of articles in all Wikipedias,[b] although it lacks millions of articles found in other editions.[1] The edition's one-billionth edit was made on 13 January 2021 by editor Steven Pruitt.[5]

English Wikipedia, often as a stand-in for Wikipedia overall, has been praised for its enablement of the democratization of knowledge, extent of coverage, unique structure, culture, and reduced degree of commercial bias. It has been criticized for exhibiting systemic bias, particularly gender bias against women and ideological bias.[6][7] While its reliability was frequently criticized in the 2000s, it has improved over time, receiving greater praise in the late 2010s and throughout the 2020s,[8][6][9][c] having become an important fact-checking site.[10][11] English Wikipedia has been characterized as having less cultural bias than other language editions due to its broader editor base.[2]

Articles

Screenshot of Wikipedia's article on Earth, 18 January 2023
Opening English Wikipedia's main page with Mozilla Firefox 99 on Ubuntu 20.04
The English Wikipedia surpassed seven million articles on 28 May 2025.[12] In November 2022, the total volume of the compressed texts of its articles amounted to 20 gigabytes.[13]

The edition's one-billionth edit was made on 13 January 2021 by Ser Amantio di Nicolao (Steven Pruitt) who as of that date is the user with the highest number of edits on the English Wikipedia, at over four million.[5] Currently, there are 7,107,928 articles created with 955,102 files. The encyclopedia is home to 10.8% of articles in all Wikipedias (down from more than 50% in 2003).[14][15] The English Wikipedia currently has 50,685,466 registered accounts of which 830 are administrators.

Bureaucracy
Editors of the English Wikipedia have pioneered some ideas as conventions, policies or features which were later adopted by Wikipedia editions in some of the other languages. These ideas include "featured articles",[16] the neutral-point-of-view policy,[17] navigation templates,[18] the sorting of short "stub" articles into sub-categories,[19] dispute resolution mechanisms such as mediation and arbitration,[20] and weekly collaborations.[21]

Wikipedians
Main article: Wikipedian

The countries in which the English Wikipedia is the most popular language version of Wikipedia are shown in red.

Number of volunteer editors on the English Wikipedia over time

Edits to English Wikipedia by country as of January 2022

The English Wikipedia (marked blue in the graph) is the most-read version of Wikipedia, accounting for 48% of the website's global traffic as of 2021.

The English Wikipedia has consistently been the most edited Wikipedia language version.
The English Wikipedia reached 4,000,000 registered user accounts on 1 April 2007,[22] over a year since the millionth Wikipedian registered an account in February 2006.[23]

Over 1,100,000 volunteer editors have edited Wikipedia more than 10 times.[24] Over 30,000 editors perform more than 5 edits per month, and over 3,000 perform more than 100 edits per month.[25]

On 1 March 2014, The Economist, in an article titled "The Future of Wikipedia", cited a trend analysis concerning data published by the Wikimedia Foundation stating that "[t]he number of editors for the English-language version has fallen by a third in seven years."[26] The attrition rate for active editors in English Wikipedia was cited by The Economist as substantially in contrast to statistics for Wikipedia in other languages (non-English Wikipedia). The Economist reported that the number of contributors with an average of five or more edits per month was relatively constant since 2008 for Wikipedia in other languages at approximately 42,000 editors within narrow seasonal variances of about 2,000 editors up or down. The number of active editors in English Wikipedia, by "sharp" comparison, was cited as peaking in 2007 at approximately 50,000 and dropping to 30,000 by the start of 2014.

The trend analysis published in The Economist presents Wikipedia in other languages (non-English Wikipedia) as successful in retaining their active editors on a renewable and sustained basis, with their numbers remaining relatively constant at approximately 42,000.[26]

The English Wikipedia has the Arbitration Committee (also known as ArbCom) that consists of a panel of editors that imposes binding rulings with regard to disputes between other editors of the online encyclopedia.[27] It was created by Jimmy Wales on 4 December 2003 as an extension of the decision-making power he had formerly held as owner of the site.[28][29] When it was founded, the committee consisted of 12 arbitrators divided into three groups of four members each.[28][30]

In 2022, for English Wikipedia, Americans accounted for about 40% of active editors, followed by British and Indian editors accounting for about 10% of each, and Canadian and Australian at about 5%.[31]

Criticism

Two radically different versions of the Wikipedia biography Klee Irwin (now deleted)[32] presented to the public within days of each other: Wikipedia's susceptibility to edit wars and bias is an issue often raised by the project's critics.
The free online encyclopedia Wikipedia has been criticized since its creation in 2001. Most of the criticism has been directed toward its content, community of established volunteer users, process, and rules. Critics have questioned its factual reliability, the readability and organization of its articles, the lack of methodical fact-checking, and its political bias.

Concerns have also been raised about systemic bias along gender, racial, political, corporate, institutional, and national lines. Conflicts of interest arising from corporate campaigns to influence content have also been highlighted. Further concerns include the vandalism and partisanship facilitated by anonymous editing, clique behavior (from contributors as well as administrators and other top figures), social stratification between a guardian class and newer users, excessive rule-making, edit warring, and uneven policy application.

Controversies
See also: Essjay controversy and Wikipedia Seigenthaler biography incident

This "criticism" or "controversy" section may compromise the article's neutrality. Please help integrate negative information into other sections or remove undue focus on minor aspects through discussion on the talk page. (July 2023)
English varieties
A notable discussion within the English Wikipedia community concerns the preference for national variety of the English language, particularly American English and British English.[33] Various suggestions have been made, ranging from standardizing a single form of English to creating separate versions of the English Wikipedia project.[citation needed] According to a style guideline, "the English Wikipedia has no general preference for a major national variety of the language" and "an article on a topic that has strong ties to a particular English-speaking nation uses the appropriate variety of English for that nation."[34]

Disputed articles
A 2013 study from Oxford University found that the most disputed articles on the English Wikipedia tend to address broader, global issues. In contrast, articles on other languages' Wikipedias often focus on regional issues. This pattern is attributed to the status of English as a global lingua franca, leading to contributions from many editors for whom English is a second language. The study identified the most disputed entries on the English Wikipedia as George W. Bush, anarchism, Muhammad, list of WWE personnel, global warming, circumcision, United States, Jesus, race and intelligence, and Christianity.[35]

Research published in 2024 determined that several groups of connected accounts had coordinated to promote Russian propaganda narratives and state-controlled media sources in articles, related to Russian-Ukrainian relations and Russia's war with Ukraine.[36][37]

Threats against high schools
There have been reports of threats of violence against high schools made on Wikipedia.[38][39][40] In 2006, a 14-year-old was arrested for making a threat against Niles West High School on Wikipedia.[41] In 2008, Glen A. Wilson High School was the subject of such a threat.[38][39][40]

WikiProjects and assessment
Main article: WikiProject
"Good articles on Wikipedia" redirects here. For the Wikipedia project page, see Wikipedia:Good articles.
A "WikiProject" is a group of contributors who want to work together as a team to improve Wikipedia. These groups may focus on a specific topic area (for example, women's history), a specific location or a specific kind of task (for example, checking newly created pages). As of August 2022, the English Wikipedia had over 2,000 WikiProjects, for which activity varied.[42]

In 2007, in preparation for producing a print version, the English Wikipedia introduced an assessment scale of the quality of articles.[43] Articles are rated by WikiProjects. The range of quality classes begins with "Stub" (very short pages), followed by "Start", "C" and "B" (in increasing order of quality). Community peer review is needed for the article to enter one of the quality classes: either "good article", "A" or the highest, "featured article". Of the about 6.5 million articles and lists assessed as of April 2022, more than 6,000 (0.09%) are featured articles, and fewer than 4,000 (0.06%) are featured lists. One featured article per day, as selected by editors, appears on the main page of Wikipedia.[44][45]

Researcher Giacomo Poderi found that articles tend to reach featured status via the intensive work of a few editors.[46] A 2010 study found unevenness in quality among featured articles and concluded that the community process is ineffective in assessing the quality of articles.[47]

Internal news publications

The Signpost icon, showing a styled 'S'
Community-produced news publications include The Signpost.[48] Other community news publications include the "WikiWorld" web comic, the Wikipedia Weekly podcast, and newsletters of specific WikiProjects like The Bugle from WikiProject Military History and the monthly newsletter from The Guild of Copy Editors. There are a number of publications from the Wikimedia Foundation and multilingual publications such as the Wikimedia Blog and This Month in Education.

See also

Wikipedia page views by language
English Wikipedia blackout
Deletionpedia
Notes
 The other edition is Simple English Wikipedia, which uses Basic English.
 The number of articles on the English Wikipedia is shown by the MediaWiki variable {{NUMBEROFARTICLES}}, with all Wikipedias as total {{NUMBEROF|ARTICLES|total}} = 66,118,901.
 Despite this praise, Wikipedia does not recognize itself as a reliable source.
References
 Harrison, Stephen (1 September 2021). "Wikipedia Is Trying to Transcend the Limits of Human Language". Slate. Archived from the original on 30 July 2023. Retrieved 17 October 2023.
 Sato, Yumiko (19 March 2021). "Non-English Editions of Wikipedia Have a Misinformation Problem". Slate. Archived from the original on 25 August 2023. Retrieved 17 October 2023.
 Anderson, Monica; Hitlin, Paul; Atkinson, Michelle (14 January 2016). "Wikipedia at 15: Millions of readers in
"""

# %%
doc=nlp(text)

# %% [markdown]
# #POS tagging

# %%
for token in doc:
    print(f"{token.text:15}  POS: {token.pos_:10}  TAG: {token.tag_:10}  DEP: {token.dep_}  Description: {spacy.explain(token.tag_)}")
# Out:
#                 POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# "                POS: PUNCT       TAG: ``          DEP: punct  Description: opening quotation mark
# en.wikipedia.org  POS: PROPN       TAG: NNP         DEP: amod  Description: noun, proper singular
# "                POS: PUNCT       TAG: ''          DEP: punct  Description: closing quotation mark
# redirects        POS: NOUN        TAG: NNS         DEP: ROOT  Description: noun, plural
# here             POS: ADV         TAG: RB          DEP: advmod  Description: adverb
# .                POS: PUNCT       TAG: .           DEP: punct  Description: punctuation mark, sentence closer
# For              POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# the              POS: DET         TAG: DT          DEP: det  Description: determiner
# main             POS: ADJ         TAG: JJ          DEP: amod  Description: adjective (English), other noun-modifier (Chinese)
# page             POS: NOUN        TAG: NN          DEP: pobj  Description: noun, singular or mass
# ,                POS: PUNCT       TAG: ,           DEP: punct  Description: punctuation mark, comma
# see              POS: VERB        TAG: VB          DEP: ROOT  Description: verb, base form
# Main             POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
# Page             POS: PROPN       TAG: NNP         DEP: dobj  Description: noun, proper singular
# .                POS: PUNCT       TAG: .           DEP: punct  Description: punctuation mark, sentence closer
# For              POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# the              POS: DET         TAG: DT          DEP: det  Description: determiner
# version          POS: NOUN        TAG: NN          DEP: pobj  Description: noun, singular or mass
# of               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# Wikipedia        POS: PROPN       TAG: NNP         DEP: pobj  Description: noun, proper singular
# written          POS: VERB        TAG: VBN         DEP: acl  Description: verb, past participle
# in               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# Basic            POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
# English          POS: PROPN       TAG: NNP         DEP: pobj  Description: noun, proper singular
# ,                POS: PUNCT       TAG: ,           DEP: punct  Description: punctuation mark, comma
# see              POS: VERB        TAG: VB          DEP: ROOT  Description: verb, base form
# Simple           POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
# English          POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
# Wikipedia        POS: PROPN       TAG: NNP         DEP: nsubj  Description: noun, proper singular
# .                POS: PUNCT       TAG: .           DEP: punct  Description: punctuation mark, sentence closer
#
#                 POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# Favicon          POS: PROPN       TAG: NNP         DEP: nmod  Description: noun, proper singular
# of               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# Wikipedia        POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
# English          POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
# Wikipedia        POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
#
#                 POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# Wikipedia        POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
# logo             POS: NOUN        TAG: NN          DEP: pobj  Description: noun, singular or mass
# with             POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# text             POS: NOUN        TAG: NN          DEP: pobj  Description: noun, singular or mass
# :                POS: PUNCT       TAG: :           DEP: punct  Description: punctuation mark, colon or ellipsis
# WIKIPEDIA        POS: PROPN       TAG: NNP         DEP: appos  Description: noun, proper singular
# The              POS: DET         TAG: DT          DEP: det  Description: determiner
# Free             POS: ADJ         TAG: JJ          DEP: amod  Description: adjective (English), other noun-modifier (Chinese)
# Encyclopedia     POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
#
#                 POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# Screenshot       POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
#
#                 POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# Type             POS: PROPN       TAG: NNP         DEP: appos  Description: noun, proper singular
# of               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# site             POS: NOUN        TAG: NN          DEP: compound  Description: noun, singular or mass
# 	                POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# Online           POS: ADJ         TAG: JJ          DEP: amod  Description: adjective (English), other noun-modifier (Chinese)
# encyclopedia     POS: NOUN        TAG: NN          DEP: pobj  Description: noun, singular or mass
#
#                 POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# Available        POS: PROPN       TAG: NNP         DEP: amod  Description: noun, proper singular
# in               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# 	                POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# English          POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
#
#                 POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# Owner            POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
# 	                POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# Wikimedia        POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
# Foundation       POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
#
#                 POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# Founder(s        POS: NOUN        TAG: NN          DEP: pobj  Description: noun, singular or mass
# )                POS: PUNCT       TAG: -RRB-       DEP: punct  Description: right round bracket
# 	                POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# Jimmy            POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
# Wales            POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
#
#                 POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# Larry            POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
# Sanger           POS: PROPN       TAG: NNP         DEP: nmod  Description: noun, proper singular
#
#                 POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# Editors          POS: NOUN        TAG: NNS         DEP: appos  Description: noun, plural
# 	                POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# English          POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
# Wikipedia        POS: PROPN       TAG: NNP         DEP: appos  Description: noun, proper singular
# community        POS: NOUN        TAG: NN          DEP: compound  Description: noun, singular or mass
#
#                 POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# URL              POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
# 	                POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# en.wikipedia.org  POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
# Edit             POS: PROPN       TAG: NNP         DEP: ROOT  Description: noun, proper singular
# this             POS: PRON        TAG: DT          DEP: dobj  Description: determiner
# at               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# Wikidata         POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
#
#                 POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# Commercial       POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
# 	                POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# No               POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
#
#                 POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# Registration     POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
# 	                POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# Optional         POS: PROPN       TAG: NNP         DEP: pobj  Description: noun, proper singular
# ;                POS: PUNCT       TAG: :           DEP: punct  Description: punctuation mark, colon or ellipsis
# required         POS: VERB        TAG: VBN         DEP: acl  Description: verb, past participle
# for              POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# certain          POS: ADJ         TAG: JJ          DEP: amod  Description: adjective (English), other noun-modifier (Chinese)
# tasks            POS: NOUN        TAG: NNS         DEP: pobj  Description: noun, plural
#
#                 POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# Users            POS: NOUN        TAG: NNS         DEP: compound  Description: noun, plural
# 	                POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# 50.7             POS: NUM         TAG: CD          DEP: compound  Description: cardinal number
# million          POS: NUM         TAG: CD          DEP: appos  Description: cardinal number
# (                POS: PUNCT       TAG: -LRB-       DEP: punct  Description: left round bracket
# as               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# of               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# 19               POS: NUM         TAG: CD          DEP: pobj  Description: cardinal number
# December         POS: PROPN       TAG: NNP         DEP: pobj  Description: noun, proper singular
# 2025             POS: NUM         TAG: CD          DEP: nummod  Description: cardinal number
# )                POS: PUNCT       TAG: -RRB-       DEP: punct  Description: right round bracket
#
#                 POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# Launched         POS: VERB        TAG: VBD         DEP: ROOT  Description: verb, past tense
# 	                POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# 15               POS: NUM         TAG: CD          DEP: nummod  Description: cardinal number
# January          POS: PROPN       TAG: NNP         DEP: npadvmod  Description: noun, proper singular
# 2001             POS: NUM         TAG: CD          DEP: nummod  Description: cardinal number
# ;                POS: PUNCT       TAG: :           DEP: punct  Description: punctuation mark, colon or ellipsis
# 24               POS: NUM         TAG: CD          DEP: nummod  Description: cardinal number
# years            POS: NOUN        TAG: NNS         DEP: npadvmod  Description: noun, plural
# ago              POS: ADP         TAG: IN          DEP: advmod  Description: conjunction, subordinating or preposition
#
#                 POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# Content          POS: ADJ         TAG: JJ          DEP: amod  Description: adjective (English), other noun-modifier (Chinese)
# license          POS: NOUN        TAG: NN          DEP: compound  Description: noun, singular or mass
# 	                POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# Creative         POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
# Commons          POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
# Attribution/     POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
#
#                 POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# Share            POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
# -                POS: PUNCT       TAG: HYPH        DEP: punct  Description: punctuation mark, hyphen
# Alike            POS: PROPN       TAG: NNP         DEP: npadvmod  Description: noun, proper singular
# 4.0              POS: NUM         TAG: CD          DEP: appos  Description: cardinal number
# (                POS: PUNCT       TAG: -LRB-       DEP: punct  Description: left round bracket
# most             POS: ADJ         TAG: JJS         DEP: amod  Description: adjective, superlative
# text             POS: NOUN        TAG: NN          DEP: appos  Description: noun, singular or mass
# also             POS: ADV         TAG: RB          DEP: advmod  Description: adverb
# dual             POS: ADV         TAG: RB          DEP: advmod  Description: adverb
# -                POS: PUNCT       TAG: HYPH        DEP: punct  Description: punctuation mark, hyphen
# licensed         POS: VERB        TAG: VBN         DEP: relcl  Description: verb, past participle
# under            POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# GFDL             POS: PROPN       TAG: NNP         DEP: pobj  Description: noun, proper singular
# )                POS: PUNCT       TAG: -RRB-       DEP: punct  Description: right round bracket
#
#                 POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# Media            POS: NOUN        TAG: NNS         DEP: nsubj  Description: noun, plural
# licensing        POS: NOUN        TAG: NN          DEP: acl  Description: noun, singular or mass
# varies           POS: AUX         TAG: VBZ         DEP: aux  Description: verb, 3rd person singular present
#
#                 POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# Written          POS: VERB        TAG: VBN         DEP: csubj  Description: verb, past participle
# in               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# 	                POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# PHP              POS: PROPN       TAG: NNP         DEP: nmod  Description: noun, proper singular
#
#                 POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# The              POS: DET         TAG: DT          DEP: det  Description: determiner
# English          POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
# Wikipedia        POS: PROPN       TAG: NNP         DEP: pobj  Description: noun, proper singular
# is               POS: AUX         TAG: VBZ         DEP: ROOT  Description: verb, 3rd person singular present
# the              POS: DET         TAG: DT          DEP: det  Description: determiner
# primary[a        POS: NOUN        TAG: NNS         DEP: amod  Description: noun, plural
# ]                POS: X           TAG: XX          DEP: punct  Description: unknown
# English          POS: ADJ         TAG: JJ          DEP: amod  Description: adjective (English), other noun-modifier (Chinese)
# -                POS: PUNCT       TAG: HYPH        DEP: punct  Description: punctuation mark, hyphen
# language         POS: NOUN        TAG: NN          DEP: compound  Description: noun, singular or mass
# edition          POS: NOUN        TAG: NN          DEP: attr  Description: noun, singular or mass
# of               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# Wikipedia        POS: PROPN       TAG: NNP         DEP: pobj  Description: noun, proper singular
# ,                POS: PUNCT       TAG: ,           DEP: punct  Description: punctuation mark, comma
# an               POS: DET         TAG: DT          DEP: det  Description: determiner
# online           POS: ADJ         TAG: JJ          DEP: amod  Description: adjective (English), other noun-modifier (Chinese)
# encyclopedia     POS: NOUN        TAG: NN          DEP: appos  Description: noun, singular or mass
# .                POS: PUNCT       TAG: .           DEP: punct  Description: punctuation mark, sentence closer
# It               POS: PRON        TAG: PRP         DEP: nsubjpass  Description: pronoun, personal
# was              POS: AUX         TAG: VBD         DEP: auxpass  Description: verb, past tense
# created          POS: VERB        TAG: VBN         DEP: ROOT  Description: verb, past participle
# by               POS: ADP         TAG: IN          DEP: agent  Description: conjunction, subordinating or preposition
# Jimmy            POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
# Wales            POS: PROPN       TAG: NNP         DEP: pobj  Description: noun, proper singular
# and              POS: CCONJ       TAG: CC          DEP: cc  Description: conjunction, coordinating
# Larry            POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
# Sanger           POS: PROPN       TAG: NNP         DEP: conj  Description: noun, proper singular
# on               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# 15               POS: NUM         TAG: CD          DEP: nummod  Description: cardinal number
# January          POS: PROPN       TAG: NNP         DEP: pobj  Description: noun, proper singular
# 2001             POS: NUM         TAG: CD          DEP: nummod  Description: cardinal number
# ,                POS: PUNCT       TAG: ,           DEP: punct  Description: punctuation mark, comma
# as               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# Wikipedia        POS: PROPN       TAG: NNP         DEP: poss  Description: noun, proper singular
# 's               POS: PART        TAG: POS         DEP: case  Description: possessive ending
# first            POS: ADJ         TAG: JJ          DEP: amod  Description: adjective (English), other noun-modifier (Chinese)
# edition          POS: NOUN        TAG: NN          DEP: pobj  Description: noun, singular or mass
# .                POS: PUNCT       TAG: .           DEP: punct  Description: punctuation mark, sentence closer
#
#
#                POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# English          POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
# Wikipedia        POS: PROPN       TAG: NNP         DEP: nsubjpass  Description: noun, proper singular
# is               POS: AUX         TAG: VBZ         DEP: auxpass  Description: verb, 3rd person singular present
# hosted           POS: VERB        TAG: VBN         DEP: ROOT  Description: verb, past participle
# alongside        POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# other            POS: ADJ         TAG: JJ          DEP: amod  Description: adjective (English), other noun-modifier (Chinese)
# language         POS: NOUN        TAG: NN          DEP: compound  Description: noun, singular or mass
# editions         POS: NOUN        TAG: NNS         DEP: pobj  Description: noun, plural
# by               POS: ADP         TAG: IN          DEP: agent  Description: conjunction, subordinating or preposition
# the              POS: DET         TAG: DT          DEP: det  Description: determiner
# Wikimedia        POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
# Foundation       POS: PROPN       TAG: NNP         DEP: pobj  Description: noun, proper singular
# ,                POS: PUNCT       TAG: ,           DEP: punct  Description: punctuation mark, comma
# an               POS: DET         TAG: DT          DEP: det  Description: determiner
# American         POS: ADJ         TAG: JJ          DEP: amod  Description: adjective (English), other noun-modifier (Chinese)
# nonprofit        POS: ADJ         TAG: JJ          DEP: amod  Description: adjective (English), other noun-modifier (Chinese)
# organization     POS: NOUN        TAG: NN          DEP: appos  Description: noun, singular or mass
# .                POS: PUNCT       TAG: .           DEP: punct  Description: punctuation mark, sentence closer
# Its              POS: PRON        TAG: PRP$        DEP: poss  Description: pronoun, possessive
# content          POS: NOUN        TAG: NN          DEP: nsubj  Description: noun, singular or mass
# ,                POS: PUNCT       TAG: ,           DEP: punct  Description: punctuation mark, comma
# written          POS: VERB        TAG: VBN         DEP: acl  Description: verb, past participle
# independently    POS: ADV         TAG: RB          DEP: advmod  Description: adverb
# of               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# other            POS: ADJ         TAG: JJ          DEP: amod  Description: adjective (English), other noun-modifier (Chinese)
# editions         POS: NOUN        TAG: NNS         DEP: pobj  Description: noun, plural
# by               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# volunteer        POS: NOUN        TAG: NN          DEP: compound  Description: noun, singular or mass
# editors          POS: NOUN        TAG: NNS         DEP: pobj  Description: noun, plural
# known            POS: VERB        TAG: VBN         DEP: acl  Description: verb, past participle
# as               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# Wikipedians,[1   POS: PROPN       TAG: NNP         DEP: pobj  Description: noun, proper singular
# ]                POS: PUNCT       TAG: -RRB-       DEP: appos  Description: right round bracket
# is               POS: AUX         TAG: VBZ         DEP: ROOT  Description: verb, 3rd person singular present
# in               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# various          POS: ADJ         TAG: JJ          DEP: amod  Description: adjective (English), other noun-modifier (Chinese)
# varieties        POS: NOUN        TAG: NNS         DEP: pobj  Description: noun, plural
# of               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# English          POS: PROPN       TAG: NNP         DEP: pobj  Description: noun, proper singular
# while            POS: SCONJ       TAG: IN          DEP: mark  Description: conjunction, subordinating or preposition
# aiming           POS: VERB        TAG: VBG         DEP: advcl  Description: verb, gerund or present participle
# to               POS: PART        TAG: TO          DEP: aux  Description: infinitival "to"
# stay             POS: VERB        TAG: VB          DEP: xcomp  Description: verb, base form
# consistent       POS: ADJ         TAG: JJ          DEP: acomp  Description: adjective (English), other noun-modifier (Chinese)
# within           POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# articles         POS: NOUN        TAG: NNS         DEP: pobj  Description: noun, plural
# .                POS: PUNCT       TAG: .           DEP: punct  Description: punctuation mark, sentence closer
# Its              POS: PRON        TAG: PRP$        DEP: poss  Description: pronoun, possessive
# internal         POS: ADJ         TAG: JJ          DEP: amod  Description: adjective (English), other noun-modifier (Chinese)
# newspaper        POS: NOUN        TAG: NN          DEP: nsubj  Description: noun, singular or mass
# is               POS: AUX         TAG: VBZ         DEP: ROOT  Description: verb, 3rd person singular present
# The              POS: DET         TAG: DT          DEP: det  Description: determiner
# Signpost         POS: PROPN       TAG: NNP         DEP: attr  Description: noun, proper singular
# .                POS: PUNCT       TAG: .           DEP: punct  Description: punctuation mark, sentence closer
#
#
#                POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# English          POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
# Wikipedia        POS: PROPN       TAG: NNP         DEP: nsubj  Description: noun, proper singular
# is               POS: AUX         TAG: VBZ         DEP: ccomp  Description: verb, 3rd person singular present
# the              POS: DET         TAG: DT          DEP: det  Description: determiner
# most             POS: ADV         TAG: RBS         DEP: advmod  Description: adverb, superlative
# read             POS: ADJ         TAG: JJ          DEP: amod  Description: adjective (English), other noun-modifier (Chinese)
# version          POS: NOUN        TAG: NN          DEP: attr  Description: noun, singular or mass
# of               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# Wikipedia,[2][3  POS: PROPN       TAG: NNP         DEP: pobj  Description: noun, proper singular
# ]                POS: PUNCT       TAG: -RRB-       DEP: punct  Description: right round bracket
# accounting       POS: NOUN        TAG: NN          DEP: pobj  Description: noun, singular or mass
# for              POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# 48               POS: NUM         TAG: CD          DEP: nummod  Description: cardinal number
# %                POS: NOUN        TAG: NN          DEP: pobj  Description: noun, singular or mass
# of               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# Wikipedia        POS: PROPN       TAG: NNP         DEP: poss  Description: noun, proper singular
# 's               POS: PART        TAG: POS         DEP: case  Description: possessive ending
# cumulative       POS: ADJ         TAG: JJ          DEP: amod  Description: adjective (English), other noun-modifier (Chinese)
# traffic          POS: NOUN        TAG: NN          DEP: pobj  Description: noun, singular or mass
# ,                POS: PUNCT       TAG: ,           DEP: punct  Description: punctuation mark, comma
# with             POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# the              POS: DET         TAG: DT          DEP: det  Description: determiner
# remaining        POS: VERB        TAG: VBG         DEP: amod  Description: verb, gerund or present participle
# percentage       POS: NOUN        TAG: NN          DEP: compound  Description: noun, singular or mass
# split            POS: NOUN        TAG: NN          DEP: pobj  Description: noun, singular or mass
# among            POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# the              POS: DET         TAG: DT          DEP: det  Description: determiner
# other            POS: ADJ         TAG: JJ          DEP: amod  Description: adjective (English), other noun-modifier (Chinese)
# languages.[4     POS: NOUN        TAG: NN          DEP: pobj  Description: noun, singular or mass
# ]                POS: PUNCT       TAG: -RRB-       DEP: punct  Description: right round bracket
# The              POS: DET         TAG: DT          DEP: det  Description: determiner
# English          POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
# Wikipedia        POS: PROPN       TAG: NNP         DEP: nsubj  Description: noun, proper singular
# has              POS: VERB        TAG: VBZ         DEP: ROOT  Description: verb, 3rd person singular present
# the              POS: DET         TAG: DT          DEP: det  Description: determiner
# most             POS: ADJ         TAG: JJS         DEP: amod  Description: adjective, superlative
# articles         POS: NOUN        TAG: NNS         DEP: dobj  Description: noun, plural
# of               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# any              POS: DET         TAG: DT          DEP: det  Description: determiner
# edition          POS: NOUN        TAG: NN          DEP: pobj  Description: noun, singular or mass
# ,                POS: PUNCT       TAG: ,           DEP: punct  Description: punctuation mark, comma
# at               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# 7,107,928        POS: NUM         TAG: CD          DEP: pobj  Description: cardinal number
# as               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# of               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# December         POS: PROPN       TAG: NNP         DEP: pobj  Description: noun, proper singular
# 2025.[b          POS: NUM         TAG: CD          DEP: nummod  Description: cardinal number
# ]                POS: PUNCT       TAG: -RRB-       DEP: punct  Description: right round bracket
# It               POS: PRON        TAG: PRP         DEP: nsubj  Description: pronoun, personal
# contains         POS: VERB        TAG: VBZ         DEP: ROOT  Description: verb, 3rd person singular present
# 10.8             POS: NUM         TAG: CD          DEP: nummod  Description: cardinal number
# %                POS: NOUN        TAG: NN          DEP: dobj  Description: noun, singular or mass
# of               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# articles         POS: NOUN        TAG: NNS         DEP: pobj  Description: noun, plural
# in               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# all              POS: DET         TAG: DT          DEP: det  Description: determiner
# Wikipedias,[b    POS: NOUN        TAG: NN          DEP: pobj  Description: noun, singular or mass
# ]                POS: PUNCT       TAG: -RRB-       DEP: punct  Description: right round bracket
# although         POS: SCONJ       TAG: IN          DEP: mark  Description: conjunction, subordinating or preposition
# it               POS: PRON        TAG: PRP         DEP: nsubj  Description: pronoun, personal
# lacks            POS: VERB        TAG: VBZ         DEP: advcl  Description: verb, 3rd person singular present
# millions         POS: NOUN        TAG: NNS         DEP: dobj  Description: noun, plural
# of               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# articles         POS: NOUN        TAG: NNS         DEP: pobj  Description: noun, plural
# found            POS: VERB        TAG: VBN         DEP: acl  Description: verb, past participle
# in               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# other            POS: ADJ         TAG: JJ          DEP: amod  Description: adjective (English), other noun-modifier (Chinese)
# editions.[1      POS: NOUN        TAG: NN          DEP: pobj  Description: noun, singular or mass
# ]                POS: PUNCT       TAG: -RRB-       DEP: punct  Description: right round bracket
# The              POS: DET         TAG: DT          DEP: det  Description: determiner
# edition          POS: NOUN        TAG: NN          DEP: poss  Description: noun, singular or mass
# 's               POS: PART        TAG: POS         DEP: case  Description: possessive ending
# one              POS: NUM         TAG: CD          DEP: nummod  Description: cardinal number
# -                POS: PUNCT       TAG: HYPH        DEP: punct  Description: punctuation mark, hyphen
# billionth        POS: NOUN        TAG: NN          DEP: compound  Description: noun, singular or mass
# edit             POS: NOUN        TAG: NN          DEP: nsubjpass  Description: noun, singular or mass
# was              POS: AUX         TAG: VBD         DEP: auxpass  Description: verb, past tense
# made             POS: VERB        TAG: VBN         DEP: ccomp  Description: verb, past participle
# on               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# 13               POS: NUM         TAG: CD          DEP: nummod  Description: cardinal number
# January          POS: PROPN       TAG: NNP         DEP: pobj  Description: noun, proper singular
# 2021             POS: NUM         TAG: CD          DEP: nummod  Description: cardinal number
# by               POS: ADP         TAG: IN          DEP: agent  Description: conjunction, subordinating or preposition
# editor           POS: NOUN        TAG: NN          DEP: compound  Description: noun, singular or mass
# Steven           POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
# Pruitt.[5        POS: PROPN       TAG: NNP         DEP: nmod  Description: noun, proper singular
# ]                POS: PUNCT       TAG: -RRB-       DEP: punct  Description: right round bracket
#
#
#                POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# English          POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
# Wikipedia        POS: PROPN       TAG: NNP         DEP: pobj  Description: noun, proper singular
# ,                POS: PUNCT       TAG: ,           DEP: punct  Description: punctuation mark, comma
# often            POS: ADV         TAG: RB          DEP: advmod  Description: adverb
# as               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# a                POS: DET         TAG: DT          DEP: det  Description: determiner
# stand            POS: NOUN        TAG: NN          DEP: compound  Description: noun, singular or mass
# -                POS: PUNCT       TAG: HYPH        DEP: punct  Description: punctuation mark, hyphen
# in               POS: NOUN        TAG: NN          DEP: pobj  Description: noun, singular or mass
# for              POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# Wikipedia        POS: PROPN       TAG: NNP         DEP: pobj  Description: noun, proper singular
# overall          POS: ADV         TAG: RB          DEP: amod  Description: adverb
# ,                POS: PUNCT       TAG: ,           DEP: punct  Description: punctuation mark, comma
# has              POS: AUX         TAG: VBZ         DEP: aux  Description: verb, 3rd person singular present
# been             POS: AUX         TAG: VBN         DEP: auxpass  Description: verb, past participle
# praised          POS: VERB        TAG: VBN         DEP: ROOT  Description: verb, past participle
# for              POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# its              POS: PRON        TAG: PRP$        DEP: poss  Description: pronoun, possessive
# enablement       POS: NOUN        TAG: NN          DEP: pobj  Description: noun, singular or mass
# of               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# the              POS: DET         TAG: DT          DEP: det  Description: determiner
# democratization  POS: NOUN        TAG: NN          DEP: pobj  Description: noun, singular or mass
# of               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# knowledge        POS: NOUN        TAG: NN          DEP: pobj  Description: noun, singular or mass
# ,                POS: PUNCT       TAG: ,           DEP: punct  Description: punctuation mark, comma
# extent           POS: NOUN        TAG: NN          DEP: appos  Description: noun, singular or mass
# of               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# coverage         POS: NOUN        TAG: NN          DEP: pobj  Description: noun, singular or mass
# ,                POS: PUNCT       TAG: ,           DEP: punct  Description: punctuation mark, comma
# unique           POS: ADJ         TAG: JJ          DEP: amod  Description: adjective (English), other noun-modifier (Chinese)
# structure        POS: NOUN        TAG: NN          DEP: conj  Description: noun, singular or mass
# ,                POS: PUNCT       TAG: ,           DEP: punct  Description: punctuation mark, comma
# culture          POS: NOUN        TAG: NN          DEP: conj  Description: noun, singular or mass
# ,                POS: PUNCT       TAG: ,           DEP: punct  Description: punctuation mark, comma
# and              POS: CCONJ       TAG: CC          DEP: cc  Description: conjunction, coordinating
# reduced          POS: VERB        TAG: VBN         DEP: amod  Description: verb, past participle
# degree           POS: NOUN        TAG: NN          DEP: conj  Description: noun, singular or mass
# of               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# commercial       POS: ADJ         TAG: JJ          DEP: amod  Description: adjective (English), other noun-modifier (Chinese)
# bias             POS: NOUN        TAG: NN          DEP: pobj  Description: noun, singular or mass
# .                POS: PUNCT       TAG: .           DEP: punct  Description: punctuation mark, sentence closer
# It               POS: PRON        TAG: PRP         DEP: nsubjpass  Description: pronoun, personal
# has              POS: AUX         TAG: VBZ         DEP: aux  Description: verb, 3rd person singular present
# been             POS: AUX         TAG: VBN         DEP: auxpass  Description: verb, past participle
# criticized       POS: VERB        TAG: VBN         DEP: ROOT  Description: verb, past participle
# for              POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# exhibiting       POS: VERB        TAG: VBG         DEP: pcomp  Description: verb, gerund or present participle
# systemic         POS: ADJ         TAG: JJ          DEP: amod  Description: adjective (English), other noun-modifier (Chinese)
# bias             POS: NOUN        TAG: NN          DEP: dobj  Description: noun, singular or mass
# ,                POS: PUNCT       TAG: ,           DEP: punct  Description: punctuation mark, comma
# particularly     POS: ADV         TAG: RB          DEP: advmod  Description: adverb
# gender           POS: NOUN        TAG: NN          DEP: compound  Description: noun, singular or mass
# bias             POS: NOUN        TAG: NN          DEP: appos  Description: noun, singular or mass
# against          POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# women            POS: NOUN        TAG: NNS         DEP: pobj  Description: noun, plural
# and              POS: CCONJ       TAG: CC          DEP: cc  Description: conjunction, coordinating
# ideological      POS: ADJ         TAG: JJ          DEP: amod  Description: adjective (English), other noun-modifier (Chinese)
# bias.[6][7       POS: PROPN       TAG: NNP         DEP: conj  Description: noun, proper singular
# ]                POS: PUNCT       TAG: -RRB-       DEP: punct  Description: right round bracket
# While            POS: SCONJ       TAG: IN          DEP: mark  Description: conjunction, subordinating or preposition
# its              POS: PRON        TAG: PRP$        DEP: poss  Description: pronoun, possessive
# reliability      POS: NOUN        TAG: NN          DEP: nsubjpass  Description: noun, singular or mass
# was              POS: AUX         TAG: VBD         DEP: auxpass  Description: verb, past tense
# frequently       POS: ADV         TAG: RB          DEP: advmod  Description: adverb
# criticized       POS: VERB        TAG: VBN         DEP: advcl  Description: verb, past participle
# in               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# the              POS: DET         TAG: DT          DEP: det  Description: determiner
# 2000s            POS: NOUN        TAG: NNS         DEP: pobj  Description: noun, plural
# ,                POS: PUNCT       TAG: ,           DEP: punct  Description: punctuation mark, comma
# it               POS: PRON        TAG: PRP         DEP: nsubj  Description: pronoun, personal
# has              POS: AUX         TAG: VBZ         DEP: aux  Description: verb, 3rd person singular present
# improved         POS: VERB        TAG: VBN         DEP: ccomp  Description: verb, past participle
# over             POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# time             POS: NOUN        TAG: NN          DEP: pobj  Description: noun, singular or mass
# ,                POS: PUNCT       TAG: ,           DEP: punct  Description: punctuation mark, comma
# receiving        POS: VERB        TAG: VBG         DEP: advcl  Description: verb, gerund or present participle
# greater          POS: ADJ         TAG: JJR         DEP: amod  Description: adjective, comparative
# praise           POS: NOUN        TAG: NN          DEP: dobj  Description: noun, singular or mass
# in               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# the              POS: DET         TAG: DT          DEP: det  Description: determiner
# late             POS: ADJ         TAG: JJ          DEP: amod  Description: adjective (English), other noun-modifier (Chinese)
# 2010s            POS: NOUN        TAG: NNS         DEP: pobj  Description: noun, plural
# and              POS: CCONJ       TAG: CC          DEP: cc  Description: conjunction, coordinating
# throughout       POS: ADP         TAG: IN          DEP: conj  Description: conjunction, subordinating or preposition
# the              POS: DET         TAG: DT          DEP: det  Description: determiner
# 2020s,[8][6][9][c  POS: NUM         TAG: CD          DEP: pobj  Description: cardinal number
# ]                POS: PUNCT       TAG: -RRB-       DEP: punct  Description: right round bracket
# having           POS: AUX         TAG: VBG         DEP: aux  Description: verb, gerund or present participle
# become           POS: VERB        TAG: VBN         DEP: advcl  Description: verb, past participle
# an               POS: DET         TAG: DT          DEP: det  Description: determiner
# important        POS: ADJ         TAG: JJ          DEP: amod  Description: adjective (English), other noun-modifier (Chinese)
# fact             POS: NOUN        TAG: NN          DEP: npadvmod  Description: noun, singular or mass
# -                POS: PUNCT       TAG: HYPH        DEP: punct  Description: punctuation mark, hyphen
# checking         POS: VERB        TAG: VBG         DEP: amod  Description: verb, gerund or present participle
# site.[10][11     POS: NOUN        TAG: NN          DEP: attr  Description: noun, singular or mass
# ]                POS: PUNCT       TAG: -RRB-       DEP: punct  Description: right round bracket
# English          POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
# Wikipedia        POS: PROPN       TAG: NNP         DEP: nsubjpass  Description: noun, proper singular
# has              POS: AUX         TAG: VBZ         DEP: aux  Description: verb, 3rd person singular present
# been             POS: AUX         TAG: VBN         DEP: auxpass  Description: verb, past participle
# characterized    POS: VERB        TAG: VBN         DEP: ROOT  Description: verb, past participle
# as               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# having           POS: VERB        TAG: VBG         DEP: pcomp  Description: verb, gerund or present participle
# less             POS: ADJ         TAG: JJR         DEP: amod  Description: adjective, comparative
# cultural         POS: ADJ         TAG: JJ          DEP: amod  Description: adjective (English), other noun-modifier (Chinese)
# bias             POS: NOUN        TAG: NN          DEP: dobj  Description: noun, singular or mass
# than             POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# other            POS: ADJ         TAG: JJ          DEP: amod  Description: adjective (English), other noun-modifier (Chinese)
# language         POS: NOUN        TAG: NN          DEP: compound  Description: noun, singular or mass
# editions         POS: NOUN        TAG: NNS         DEP: pobj  Description: noun, plural
# due              POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# to               POS: ADP         TAG: IN          DEP: pcomp  Description: conjunction, subordinating or preposition
# its              POS: PRON        TAG: PRP$        DEP: poss  Description: pronoun, possessive
# broader          POS: ADJ         TAG: JJR         DEP: amod  Description: adjective, comparative
# editor           POS: NOUN        TAG: NN          DEP: pobj  Description: noun, singular or mass
# base.[2          POS: ADV         TAG: RB          DEP: appos  Description: adverb
# ]                POS: PUNCT       TAG: -RRB-       DEP: punct  Description: right round bracket
#
#
#                POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# Articles         POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
#
#
#                POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# Screenshot       POS: PROPN       TAG: NNP         DEP: appos  Description: noun, proper singular
# of               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# Wikipedia        POS: PROPN       TAG: NNP         DEP: poss  Description: noun, proper singular
# 's               POS: PART        TAG: POS         DEP: case  Description: possessive ending
# article          POS: NOUN        TAG: NN          DEP: pobj  Description: noun, singular or mass
# on               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# Earth            POS: PROPN       TAG: NNP         DEP: pobj  Description: noun, proper singular
# ,                POS: PUNCT       TAG: ,           DEP: punct  Description: punctuation mark, comma
# 18               POS: NUM         TAG: CD          DEP: nummod  Description: cardinal number
# January          POS: PROPN       TAG: NNP         DEP: nmod  Description: noun, proper singular
# 2023             POS: NUM         TAG: CD          DEP: nummod  Description: cardinal number
#
#                 POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# Opening          POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
# English          POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
# Wikipedia        POS: PROPN       TAG: NNP         DEP: poss  Description: noun, proper singular
# 's               POS: PART        TAG: POS         DEP: case  Description: possessive ending
# main             POS: ADJ         TAG: JJ          DEP: amod  Description: adjective (English), other noun-modifier (Chinese)
# page             POS: NOUN        TAG: NN          DEP: dobj  Description: noun, singular or mass
# ...
# English          POS: PROPN       TAG: NNP         DEP: dobj  Description: noun, proper singular
# .                POS: PUNCT       TAG: .           DEP: punct  Description: punctuation mark, sentence closer
#
#                 POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# The              POS: DET         TAG: DT          DEP: det  Description: determiner
# number           POS: NOUN        TAG: NN          DEP: nsubjpass  Description: noun, singular or mass
# of               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# articles         POS: NOUN        TAG: NNS         DEP: pobj  Description: noun, plural
# on               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# the              POS: DET         TAG: DT          DEP: det  Description: determiner
# English          POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
# Wikipedia        POS: PROPN       TAG: NNP         DEP: pobj  Description: noun, proper singular
# is               POS: AUX         TAG: VBZ         DEP: auxpass  Description: verb, 3rd person singular present
# shown            POS: VERB        TAG: VBN         DEP: ROOT  Description: verb, past participle
# by               POS: ADP         TAG: IN          DEP: agent  Description: conjunction, subordinating or preposition
# the              POS: DET         TAG: DT          DEP: det  Description: determiner
# MediaWiki        POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
# variable         POS: NOUN        TAG: NN          DEP: pobj  Description: noun, singular or mass
# {                POS: PUNCT       TAG: -LRB-       DEP: punct  Description: left round bracket
# {                POS: PUNCT       TAG: -LRB-       DEP: punct  Description: left round bracket
# NUMBEROFARTICLES  POS: NOUN        TAG: NNS         DEP: appos  Description: noun, plural
# }                POS: PUNCT       TAG: -RRB-       DEP: punct  Description: right round bracket
# }                POS: PUNCT       TAG: -RRB-       DEP: punct  Description: right round bracket
# ,                POS: PUNCT       TAG: ,           DEP: punct  Description: punctuation mark, comma
# with             POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# all              POS: DET         TAG: DT          DEP: det  Description: determiner
# Wikipedias       POS: PROPN       TAG: NNP         DEP: pobj  Description: noun, proper singular
# as               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# total            POS: ADJ         TAG: JJ          DEP: pobj  Description: adjective (English), other noun-modifier (Chinese)
# {                POS: PUNCT       TAG: -LRB-       DEP: punct  Description: left round bracket
# {                POS: PUNCT       TAG: -LRB-       DEP: punct  Description: left round bracket
# NUMBEROF|ARTICLES|total  POS: ADJ         TAG: JJ          DEP: appos  Description: adjective (English), other noun-modifier (Chinese)
# }                POS: PUNCT       TAG: -RRB-       DEP: punct  Description: right round bracket
# }                POS: PUNCT       TAG: -RRB-       DEP: punct  Description: right round bracket
# =                POS: NUM         TAG: CD          DEP: prep  Description: cardinal number
# 66,118,901       POS: NUM         TAG: CD          DEP: npadvmod  Description: cardinal number
# .                POS: PUNCT       TAG: .           DEP: punct  Description: punctuation mark, sentence closer
#
#                 POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# Despite          POS: SCONJ       TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# this             POS: DET         TAG: DT          DEP: det  Description: determiner
# praise           POS: NOUN        TAG: NN          DEP: pobj  Description: noun, singular or mass
# ,                POS: PUNCT       TAG: ,           DEP: punct  Description: punctuation mark, comma
# Wikipedia        POS: PROPN       TAG: NNP         DEP: nsubj  Description: noun, proper singular
# does             POS: AUX         TAG: VBZ         DEP: aux  Description: verb, 3rd person singular present
# not              POS: PART        TAG: RB          DEP: neg  Description: adverb
# recognize        POS: VERB        TAG: VB          DEP: ROOT  Description: verb, base form
# itself           POS: PRON        TAG: PRP         DEP: dobj  Description: pronoun, personal
# as               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# a                POS: DET         TAG: DT          DEP: det  Description: determiner
# reliable         POS: ADJ         TAG: JJ          DEP: amod  Description: adjective (English), other noun-modifier (Chinese)
# source           POS: NOUN        TAG: NN          DEP: pobj  Description: noun, singular or mass
# .                POS: PUNCT       TAG: .           DEP: punct  Description: punctuation mark, sentence closer
#
#                 POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# References       POS: NOUN        TAG: NNS         DEP: compound  Description: noun, plural
#
#                 POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# Harrison         POS: PROPN       TAG: NNP         DEP: ROOT  Description: noun, proper singular
# ,                POS: PUNCT       TAG: ,           DEP: punct  Description: punctuation mark, comma
# Stephen          POS: PROPN       TAG: NNP         DEP: appos  Description: noun, proper singular
# (                POS: PUNCT       TAG: -LRB-       DEP: punct  Description: left round bracket
# 1                POS: NUM         TAG: CD          DEP: appos  Description: cardinal number
# September        POS: PROPN       TAG: NNP         DEP: appos  Description: noun, proper singular
# 2021             POS: NUM         TAG: CD          DEP: nummod  Description: cardinal number
# )                POS: PUNCT       TAG: -RRB-       DEP: punct  Description: right round bracket
# .                POS: PUNCT       TAG: .           DEP: punct  Description: punctuation mark, sentence closer
# "                POS: PUNCT       TAG: ``          DEP: punct  Description: opening quotation mark
# Wikipedia        POS: PROPN       TAG: NNP         DEP: nsubj  Description: noun, proper singular
# Is               POS: AUX         TAG: VBZ         DEP: aux  Description: verb, 3rd person singular present
# Trying           POS: VERB        TAG: VBG         DEP: ROOT  Description: verb, gerund or present participle
# to               POS: PART        TAG: TO          DEP: aux  Description: infinitival "to"
# Transcend        POS: VERB        TAG: VB          DEP: xcomp  Description: verb, base form
# the              POS: DET         TAG: DT          DEP: det  Description: determiner
# Limits           POS: NOUN        TAG: NNS         DEP: dobj  Description: noun, plural
# of               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# Human            POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
# Language         POS: PROPN       TAG: NNP         DEP: pobj  Description: noun, proper singular
# "                POS: PUNCT       TAG: ''          DEP: punct  Description: closing quotation mark
# .                POS: PUNCT       TAG: .           DEP: punct  Description: punctuation mark, sentence closer
# Slate            POS: NOUN        TAG: NN          DEP: ROOT  Description: noun, singular or mass
# .                POS: PUNCT       TAG: .           DEP: punct  Description: punctuation mark, sentence closer
# Archived         POS: VERB        TAG: VBN         DEP: ROOT  Description: verb, past participle
# from             POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# the              POS: DET         TAG: DT          DEP: det  Description: determiner
# original         POS: NOUN        TAG: NN          DEP: pobj  Description: noun, singular or mass
# on               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# 30               POS: NUM         TAG: CD          DEP: nummod  Description: cardinal number
# July             POS: PROPN       TAG: NNP         DEP: pobj  Description: noun, proper singular
# 2023             POS: NUM         TAG: CD          DEP: nummod  Description: cardinal number
# .                POS: PUNCT       TAG: .           DEP: punct  Description: punctuation mark, sentence closer
# Retrieved        POS: VERB        TAG: VBN         DEP: ROOT  Description: verb, past participle
# 17               POS: NUM         TAG: CD          DEP: dobj  Description: cardinal number
# October          POS: PROPN       TAG: NNP         DEP: npadvmod  Description: noun, proper singular
# 2023             POS: NUM         TAG: CD          DEP: nummod  Description: cardinal number
# .                POS: PUNCT       TAG: .           DEP: punct  Description: punctuation mark, sentence closer
#
#                 POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# Sato             POS: PROPN       TAG: NNP         DEP: ROOT  Description: noun, proper singular
# ,                POS: PUNCT       TAG: ,           DEP: punct  Description: punctuation mark, comma
# Yumiko           POS: PROPN       TAG: NNP         DEP: appos  Description: noun, proper singular
# (                POS: PUNCT       TAG: -LRB-       DEP: punct  Description: left round bracket
# 19               POS: NUM         TAG: CD          DEP: nummod  Description: cardinal number
# March            POS: PROPN       TAG: NNP         DEP: npadvmod  Description: noun, proper singular
# 2021             POS: NUM         TAG: CD          DEP: nummod  Description: cardinal number
# )                POS: PUNCT       TAG: -RRB-       DEP: punct  Description: right round bracket
# .                POS: PUNCT       TAG: .           DEP: punct  Description: punctuation mark, sentence closer
# "                POS: PUNCT       TAG: ``          DEP: punct  Description: opening quotation mark
# Non              POS: ADJ         TAG: JJ          DEP: compound  Description: adjective (English), other noun-modifier (Chinese)
# -                POS: ADJ         TAG: JJ          DEP: amod  Description: adjective (English), other noun-modifier (Chinese)
# English          POS: ADJ         TAG: JJ          DEP: amod  Description: adjective (English), other noun-modifier (Chinese)
# Editions         POS: PROPN       TAG: NNPS        DEP: nsubj  Description: noun, proper plural
# of               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# Wikipedia        POS: PROPN       TAG: NNP         DEP: pobj  Description: noun, proper singular
# Have             POS: VERB        TAG: VBP         DEP: ROOT  Description: verb, non-3rd person singular present
# a                POS: DET         TAG: DT          DEP: det  Description: determiner
# Misinformation   POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
# Problem          POS: PROPN       TAG: NNP         DEP: dobj  Description: noun, proper singular
# "                POS: PUNCT       TAG: ''          DEP: punct  Description: closing quotation mark
# .                POS: PUNCT       TAG: .           DEP: punct  Description: punctuation mark, sentence closer
# Slate            POS: NOUN        TAG: NN          DEP: ROOT  Description: noun, singular or mass
# .                POS: PUNCT       TAG: .           DEP: punct  Description: punctuation mark, sentence closer
# Archived         POS: VERB        TAG: VBN         DEP: ROOT  Description: verb, past participle
# from             POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# the              POS: DET         TAG: DT          DEP: det  Description: determiner
# original         POS: ADJ         TAG: JJ          DEP: pobj  Description: adjective (English), other noun-modifier (Chinese)
# on               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# 25               POS: NUM         TAG: CD          DEP: nummod  Description: cardinal number
# August           POS: PROPN       TAG: NNP         DEP: pobj  Description: noun, proper singular
# 2023             POS: NUM         TAG: CD          DEP: nummod  Description: cardinal number
# .                POS: PUNCT       TAG: .           DEP: punct  Description: punctuation mark, sentence closer
# Retrieved        POS: VERB        TAG: VBN         DEP: ROOT  Description: verb, past participle
# 17               POS: NUM         TAG: CD          DEP: dobj  Description: cardinal number
# October          POS: PROPN       TAG: NNP         DEP: npadvmod  Description: noun, proper singular
# 2023             POS: NUM         TAG: CD          DEP: nummod  Description: cardinal number
# .                POS: PUNCT       TAG: .           DEP: punct  Description: punctuation mark, sentence closer
#
#                 POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# Anderson         POS: PROPN       TAG: NNP         DEP: ROOT  Description: noun, proper singular
# ,                POS: PUNCT       TAG: ,           DEP: punct  Description: punctuation mark, comma
# Monica           POS: PROPN       TAG: NNP         DEP: npadvmod  Description: noun, proper singular
# ;                POS: PUNCT       TAG: :           DEP: punct  Description: punctuation mark, colon or ellipsis
# Hitlin           POS: PROPN       TAG: NNP         DEP: conj  Description: noun, proper singular
# ,                POS: PUNCT       TAG: ,           DEP: punct  Description: punctuation mark, comma
# Paul             POS: PROPN       TAG: NNP         DEP: conj  Description: noun, proper singular
# ;                POS: PUNCT       TAG: :           DEP: punct  Description: punctuation mark, colon or ellipsis
# Atkinson         POS: PROPN       TAG: NNP         DEP: conj  Description: noun, proper singular
# ,                POS: PUNCT       TAG: ,           DEP: punct  Description: punctuation mark, comma
# Michelle         POS: PROPN       TAG: NNP         DEP: conj  Description: noun, proper singular
# (                POS: PUNCT       TAG: -LRB-       DEP: punct  Description: left round bracket
# 14               POS: NUM         TAG: CD          DEP: punct  Description: cardinal number
# January          POS: PROPN       TAG: NNP         DEP: npadvmod  Description: noun, proper singular
# 2016             POS: NUM         TAG: CD          DEP: nummod  Description: cardinal number
# )                POS: PUNCT       TAG: -RRB-       DEP: punct  Description: right round bracket
# .                POS: PUNCT       TAG: .           DEP: punct  Description: punctuation mark, sentence closer
# "                POS: PUNCT       TAG: ``          DEP: punct  Description: opening quotation mark
# Wikipedia        POS: PROPN       TAG: NNP         DEP: ROOT  Description: noun, proper singular
# at               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# 15               POS: NUM         TAG: CD          DEP: pobj  Description: cardinal number
# :                POS: PUNCT       TAG: :           DEP: punct  Description: punctuation mark, colon or ellipsis
# Millions         POS: NOUN        TAG: NNS         DEP: appos  Description: noun, plural
# of               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# readers          POS: NOUN        TAG: NNS         DEP: pobj  Description: noun, plural
# in               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
#
#                 POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace

# %% [markdown]
# #Dependency Parsing

# %%
for token in doc:
    print(f"{token.text:12} <--{token.dep_:10}-- {token.head.text}")
# Out:
#             <--dep       -- redirects
# "            <--punct     -- redirects
# en.wikipedia.org <--amod      -- redirects
# "            <--punct     -- redirects
# redirects    <--ROOT      -- redirects
# here         <--advmod    -- redirects
# .            <--punct     -- redirects
# For          <--prep      -- see
# the          <--det       -- page
# main         <--amod      -- page
# page         <--pobj      -- For
# ,            <--punct     -- see
# see          <--ROOT      -- see
# Main         <--compound  -- Page
# Page         <--dobj      -- see
# .            <--punct     -- see
# For          <--prep      -- see
# the          <--det       -- version
# version      <--pobj      -- For
# of           <--prep      -- version
# Wikipedia    <--pobj      -- of
# written      <--acl       -- version
# in           <--prep      -- written
# Basic        <--compound  -- English
# English      <--pobj      -- in
# ,            <--punct     -- see
# see          <--ROOT      -- see
# Simple       <--compound  -- Wikipedia
# English      <--compound  -- Wikipedia
# Wikipedia    <--nsubj     -- see
# .            <--punct     -- see
#
#             <--dep       -- .
# Favicon      <--nmod      -- Edit
# of           <--prep      -- Favicon
# Wikipedia    <--compound  -- Wikipedia
# English      <--compound  -- Wikipedia
# Wikipedia    <--compound  -- Wikipedia
#
#             <--dep       -- Wikipedia
# Wikipedia    <--compound  -- logo
# logo         <--pobj      -- of
# with         <--prep      -- logo
# text         <--pobj      -- with
# :            <--punct     -- Favicon
# WIKIPEDIA    <--appos     -- Favicon
# The          <--det       -- Type
# Free         <--amod      -- Type
# Encyclopedia <--compound  -- Type
#
#             <--dep       -- Encyclopedia
# Screenshot   <--compound  -- Type
#
#             <--dep       -- Screenshot
# Type         <--appos     -- WIKIPEDIA
# of           <--prep      -- Type
# site         <--compound  -- encyclopedia
# 	            <--dep       -- site
# Online       <--amod      -- encyclopedia
# encyclopedia <--pobj      -- of
#
#             <--dep       -- encyclopedia
# Available    <--amod      -- WIKIPEDIA
# in           <--prep      -- Available
# 	            <--dep       -- in
# English      <--compound  -- Founder(s
#
#             <--dep       -- English
# Owner        <--compound  -- Founder(s
# 	            <--dep       -- Owner
# Wikimedia    <--compound  -- Founder(s
# Foundation   <--compound  -- Founder(s
#
#             <--dep       -- Foundation
# Founder(s    <--pobj      -- in
# )            <--punct     -- WIKIPEDIA
# 	            <--dep       -- )
# Jimmy        <--compound  -- Wales
# Wales        <--compound  -- Sanger
#
#             <--dep       -- Wales
# Larry        <--compound  -- Sanger
# Sanger       <--nmod      -- Edit
#
#             <--dep       -- Sanger
# Editors      <--appos     -- Sanger
# 	            <--dep       -- Editors
# English      <--compound  -- Wikipedia
# Wikipedia    <--appos     -- Editors
# community    <--compound  -- URL
#
#             <--dep       -- community
# URL          <--compound  -- Edit
# 	            <--dep       -- URL
# en.wikipedia.org <--compound  -- Edit
# Edit         <--ROOT      -- Edit
# this         <--dobj      -- Edit
# at           <--prep      -- Edit
# Wikidata     <--compound  -- Optional
#
#             <--dep       -- Wikidata
# Commercial   <--compound  -- Optional
# 	            <--dep       -- Commercial
# No           <--compound  -- Optional
#
#             <--dep       -- No
# Registration <--compound  -- Optional
# 	            <--dep       -- Registration
# Optional     <--pobj      -- at
# ;            <--punct     -- Edit
# required     <--acl       -- Edit
# for          <--prep      -- required
# certain      <--amod      -- tasks
# tasks        <--pobj      -- for
#
#             <--dep       -- tasks
# Users        <--compound  -- million
# 	            <--dep       -- Users
# 50.7         <--compound  -- million
# million      <--appos     -- tasks
# (            <--punct     -- million
# as           <--prep      -- required
# of           <--prep      -- as
# 19           <--pobj      -- of
# December     <--pobj      -- of
# 2025         <--nummod    -- December
# )            <--punct     -- required
#
#             <--dep       -- )
# Launched     <--ROOT      -- Launched
# 	            <--dep       -- Launched
# 15           <--nummod    -- January
# January      <--npadvmod  -- Launched
# 2001         <--nummod    -- January
# ;            <--punct     -- Launched
# 24           <--nummod    -- years
# years        <--npadvmod  -- ago
# ago          <--advmod    -- Alike
#
#             <--dep       -- ago
# Content      <--amod      -- license
# license      <--compound  -- Alike
# 	            <--dep       -- license
# Creative     <--compound  -- Attribution/
# Commons      <--compound  -- Attribution/
# Attribution/ <--compound  -- Alike
#
#             <--dep       -- Attribution/
# Share        <--compound  -- Alike
# -            <--punct     -- Alike
# Alike        <--npadvmod  -- Launched
# 4.0          <--appos     -- Alike
# (            <--punct     -- text
# most         <--amod      -- text
# text         <--appos     -- Alike
# also         <--advmod    -- licensed
# dual         <--advmod    -- licensed
# -            <--punct     -- licensed
# licensed     <--relcl     -- text
# under        <--prep      -- licensed
# GFDL         <--pobj      -- under
# )            <--punct     -- text
#
#             <--dep       -- )
# Media        <--nsubj     -- varies
# licensing    <--acl       -- Media
# varies       <--aux       -- Written
#
#             <--dep       -- varies
# Written      <--csubj     -- is
# in           <--prep      -- Written
# 	            <--dep       -- in
# PHP          <--nmod      -- Wikipedia
#
#             <--dep       -- PHP
# The          <--det       -- Wikipedia
# English      <--compound  -- Wikipedia
# Wikipedia    <--pobj      -- in
# is           <--ROOT      -- is
# the          <--det       -- edition
# primary[a    <--amod      -- edition
# ]            <--punct     -- edition
# English      <--amod      -- language
# -            <--punct     -- language
# language     <--compound  -- edition
# edition      <--attr      -- is
# of           <--prep      -- edition
# Wikipedia    <--pobj      -- of
# ,            <--punct     -- Wikipedia
# an           <--det       -- encyclopedia
# online       <--amod      -- encyclopedia
# encyclopedia <--appos     -- Wikipedia
# .            <--punct     -- is
# It           <--nsubjpass -- created
# was          <--auxpass   -- created
# created      <--ROOT      -- created
# by           <--agent     -- created
# Jimmy        <--compound  -- Wales
# Wales        <--pobj      -- by
# and          <--cc        -- Wales
# Larry        <--compound  -- Sanger
# Sanger       <--conj      -- Wales
# on           <--prep      -- created
# 15           <--nummod    -- January
# January      <--pobj      -- on
# 2001         <--nummod    -- January
# ,            <--punct     -- January
# as           <--prep      -- created
# Wikipedia    <--poss      -- edition
# 's           <--case      -- Wikipedia
# first        <--amod      -- edition
# edition      <--pobj      -- as
# .            <--punct     -- created
#
#
#            <--dep       -- .
# English      <--compound  -- Wikipedia
# Wikipedia    <--nsubjpass -- hosted
# is           <--auxpass   -- hosted
# hosted       <--ROOT      -- hosted
# alongside    <--prep      -- hosted
# other        <--amod      -- editions
# language     <--compound  -- editions
# editions     <--pobj      -- alongside
# by           <--agent     -- hosted
# the          <--det       -- Foundation
# Wikimedia    <--compound  -- Foundation
# Foundation   <--pobj      -- by
# ,            <--punct     -- Foundation
# an           <--det       -- organization
# American     <--amod      -- organization
# nonprofit    <--amod      -- organization
# organization <--appos     -- Foundation
# .            <--punct     -- hosted
# Its          <--poss      -- content
# content      <--nsubj     -- is
# ,            <--punct     -- content
# written      <--acl       -- content
# independently <--advmod    -- written
# of           <--prep      -- written
# other        <--amod      -- editions
# editions     <--pobj      -- of
# by           <--prep      -- editions
# volunteer    <--compound  -- editors
# editors      <--pobj      -- by
# known        <--acl       -- editors
# as           <--prep      -- known
# Wikipedians,[1 <--pobj      -- as
# ]            <--appos     -- content
# is           <--ROOT      -- is
# in           <--prep      -- is
# various      <--amod      -- varieties
# varieties    <--pobj      -- in
# of           <--prep      -- varieties
# English      <--pobj      -- of
# while        <--mark      -- aiming
# aiming       <--advcl     -- is
# to           <--aux       -- stay
# stay         <--xcomp     -- aiming
# consistent   <--acomp     -- stay
# within       <--prep      -- stay
# articles     <--pobj      -- within
# .            <--punct     -- is
# Its          <--poss      -- newspaper
# internal     <--amod      -- newspaper
# newspaper    <--nsubj     -- is
# is           <--ROOT      -- is
# The          <--det       -- Signpost
# Signpost     <--attr      -- is
# .            <--punct     -- is
#
#
#            <--dep       -- .
# English      <--compound  -- Wikipedia
# Wikipedia    <--nsubj     -- is
# is           <--ccomp     -- has
# the          <--det       -- version
# most         <--advmod    -- read
# read         <--amod      -- version
# version      <--attr      -- is
# of           <--prep      -- version
# Wikipedia,[2][3 <--pobj      -- of
# ]            <--punct     -- Wikipedia,[2][3
# accounting   <--pobj      -- of
# for          <--prep      -- accounting
# 48           <--nummod    -- %
# %            <--pobj      -- for
# of           <--prep      -- %
# Wikipedia    <--poss      -- traffic
# 's           <--case      -- Wikipedia
# cumulative   <--amod      -- traffic
# traffic      <--pobj      -- of
# ,            <--punct     -- version
# with         <--prep      -- version
# the          <--det       -- split
# remaining    <--amod      -- split
# percentage   <--compound  -- split
# split        <--pobj      -- with
# among        <--prep      -- split
# the          <--det       -- languages.[4
# other        <--amod      -- languages.[4
# languages.[4 <--pobj      -- among
# ]            <--punct     -- has
# The          <--det       -- Wikipedia
# English      <--compound  -- Wikipedia
# Wikipedia    <--nsubj     -- has
# has          <--ROOT      -- has
# the          <--det       -- articles
# most         <--amod      -- articles
# articles     <--dobj      -- has
# of           <--prep      -- articles
# any          <--det       -- edition
# edition      <--pobj      -- of
# ,            <--punct     -- has
# at           <--prep      -- has
# 7,107,928    <--pobj      -- at
# as           <--prep      -- 7,107,928
# of           <--prep      -- as
# December     <--pobj      -- of
# 2025.[b      <--nummod    -- December
# ]            <--punct     -- has
# It           <--nsubj     -- contains
# contains     <--ROOT      -- contains
# 10.8         <--nummod    -- %
# %            <--dobj      -- contains
# of           <--prep      -- %
# articles     <--pobj      -- of
# in           <--prep      -- contains
# all          <--det       -- Wikipedias,[b
# Wikipedias,[b <--pobj      -- in
# ]            <--punct     -- contains
# although     <--mark      -- lacks
# it           <--nsubj     -- lacks
# lacks        <--advcl     -- contains
# millions     <--dobj      -- lacks
# of           <--prep      -- millions
# articles     <--pobj      -- of
# found        <--acl       -- articles
# in           <--prep      -- found
# other        <--amod      -- editions.[1
# editions.[1  <--pobj      -- in
# ]            <--punct     -- contains
# The          <--det       -- edition
# edition      <--poss      -- edit
# 's           <--case      -- edition
# one          <--nummod    -- billionth
# -            <--punct     -- billionth
# billionth    <--compound  -- edit
# edit         <--nsubjpass -- made
# was          <--auxpass   -- made
# made         <--ccomp     -- praised
# on           <--prep      -- made
# 13           <--nummod    -- January
# January      <--pobj      -- on
# 2021         <--nummod    -- January
# by           <--agent     -- made
# editor       <--compound  -- Wikipedia
# Steven       <--compound  -- Pruitt.[5
# Pruitt.[5    <--nmod      -- Wikipedia
# ]            <--punct     -- Pruitt.[5
#
#
#            <--dep       -- ]
# English      <--compound  -- Wikipedia
# Wikipedia    <--pobj      -- by
# ,            <--punct     -- made
# often        <--advmod    -- as
# as           <--prep      -- made
# a            <--det       -- in
# stand        <--compound  -- in
# -            <--punct     -- in
# in           <--pobj      -- as
# for          <--prep      -- in
# Wikipedia    <--pobj      -- for
# overall      <--amod      -- as
# ,            <--punct     -- made
# has          <--aux       -- praised
# been         <--auxpass   -- praised
# praised      <--ROOT      -- praised
# for          <--prep      -- praised
# its          <--poss      -- enablement
# enablement   <--pobj      -- for
# of           <--prep      -- enablement
# the          <--det       -- democratization
# democratization <--pobj      -- of
# of           <--prep      -- democratization
# knowledge    <--pobj      -- of
# ,            <--punct     -- enablement
# extent       <--appos     -- enablement
# of           <--prep      -- extent
# coverage     <--pobj      -- of
# ,            <--punct     -- extent
# unique       <--amod      -- structure
# structure    <--conj      -- extent
# ,            <--punct     -- structure
# culture      <--conj      -- structure
# ,            <--punct     -- culture
# and          <--cc        -- culture
# reduced      <--amod      -- degree
# degree       <--conj      -- culture
# of           <--prep      -- degree
# commercial   <--amod      -- bias
# bias         <--pobj      -- of
# .            <--punct     -- praised
# It           <--nsubjpass -- criticized
# has          <--aux       -- criticized
# been         <--auxpass   -- criticized
# criticized   <--ROOT      -- criticized
# for          <--prep      -- criticized
# exhibiting   <--pcomp     -- for
# systemic     <--amod      -- bias
# bias         <--dobj      -- exhibiting
# ,            <--punct     -- bias
# particularly <--advmod    -- bias
# gender       <--compound  -- bias
# bias         <--appos     -- bias
# against      <--prep      -- bias
# women        <--pobj      -- against
# and          <--cc        -- women
# ideological  <--amod      -- bias.[6][7
# bias.[6][7   <--conj      -- women
# ]            <--punct     -- criticized
# While        <--mark      -- criticized
# its          <--poss      -- reliability
# reliability  <--nsubjpass -- criticized
# was          <--auxpass   -- criticized
# frequently   <--advmod    -- criticized
# criticized   <--advcl     -- improved
# in           <--prep      -- criticized
# the          <--det       -- 2000s
# 2000s        <--pobj      -- in
# ,            <--punct     -- improved
# it           <--nsubj     -- improved
# has          <--aux       -- improved
# improved     <--ccomp     -- characterized
# over         <--prep      -- improved
# time         <--pobj      -- over
# ,            <--punct     -- improved
# receiving    <--advcl     -- improved
# greater      <--amod      -- praise
# praise       <--dobj      -- receiving
# in           <--prep      -- receiving
# the          <--det       -- 2010s
# late         <--amod      -- 2010s
# 2010s        <--pobj      -- in
# and          <--cc        -- in
# throughout   <--conj      -- in
# the          <--det       -- 2020s,[8][6][9][c
# 2020s,[8][6][9][c <--pobj      -- throughout
# ]            <--punct     -- receiving
# having       <--aux       -- become
# become       <--advcl     -- receiving
# an           <--det       -- site.[10][11
# important    <--amod      -- site.[10][11
# fact         <--npadvmod  -- checking
# -            <--punct     -- checking
# checking     <--amod      -- site.[10][11
# site.[10][11 <--attr      -- become
# ]            <--punct     -- characterized
# English      <--compound  -- Wikipedia
# Wikipedia    <--nsubjpass -- characterized
# has          <--aux       -- characterized
# been         <--auxpass   -- characterized
# characterized <--ROOT      -- characterized
# as           <--prep      -- characterized
# having       <--pcomp     -- as
# less         <--amod      -- bias
# cultural     <--amod      -- bias
# bias         <--dobj      -- having
# than         <--prep      -- bias
# other        <--amod      -- editions
# language     <--compound  -- editions
# editions     <--pobj      -- than
# due          <--prep      -- having
# to           <--pcomp     -- due
# its          <--poss      -- editor
# broader      <--amod      -- editor
# editor       <--pobj      -- due
# base.[2      <--appos     -- editor
# ]            <--punct     -- editor
#
#
#            <--dep       -- ]
# Articles     <--compound  -- Screenshot
#
#
#            <--dep       -- Articles
# Screenshot   <--appos     -- editor
# of           <--prep      -- Screenshot
# Wikipedia    <--poss      -- article
# 's           <--case      -- Wikipedia
# article      <--pobj      -- of
# on           <--prep      -- article
# Earth        <--pobj      -- on
# ,            <--punct     -- Screenshot
# 18           <--nummod    -- January
# January      <--nmod      -- page
# 2023         <--nummod    -- January
#
#             <--dep       -- 2023
# Opening      <--compound  -- Wikipedia
# English      <--compound  -- Wikipedia
# Wikipedia    <--poss      -- page
# 's           <--case      -- Wikipedia
# main         <--amod      -- page
# page         <--dobj      -- having
# with         <--prep      -- page
# Mozilla      <--compound  -- Firefox
# Firefox      <--pobj      -- with
# 99           <--nummod    -- Firefox
# on           <--prep      -- page
# Ubuntu       <--pobj      -- on
# 20.04        <--nummod    -- Ubuntu
#
#             <--dep       -- 20.04
# The          <--det       -- Wikipedia
# English      <--compound  -- Wikipedia
# Wikipedia    <--nsubj     -- surpassed
# surpassed    <--ROOT      -- surpassed
# seven        <--compound  -- million
# million      <--nummod    -- articles
# articles     <--dobj      -- surpassed
# on           <--prep      -- surpassed
# 28           <--nummod    -- 2025.[12
# May          <--compound  -- 2025.[12
# 2025.[12     <--pobj      -- on
# ]            <--punct     -- surpassed
# In           <--prep      -- amounted
# November     <--pobj      -- In
# 2022         <--nummod    -- November
# ,            <--punct     -- amounted
# the          <--det       -- volume
# total        <--amod      -- volume
# volume       <--nsubj     -- amounted
# of           <--prep      -- volume
# the          <--det       -- texts
# compressed   <--amod      -- texts
# texts        <--pobj      -- of
# of           <--prep      -- texts
# its          <--poss      -- articles
# articles     <--pobj      -- of
# amounted     <--ROOT      -- amounted
# to           <--prep      -- amounted
# 20           <--nummod    -- gigabytes.[13
# gigabytes.[13 <--pobj      -- to
# ]            <--punct     -- gigabytes.[13
#
#
#            <--dep       -- ]
# The          <--det       -- edition
# edition      <--poss      -- edit
# 's           <--case      -- edition
# one          <--nummod    -- billionth
# -            <--punct     -- billionth
# billionth    <--compound  -- edit
# edit         <--nsubjpass -- made
# was          <--auxpass   -- made
# made         <--conj      -- amounted
# on           <--prep      -- made
# 13           <--nummod    -- January
# January      <--pobj      -- on
# 2021         <--nummod    -- January
# by           <--agent     -- made
# Ser          <--compound  -- Amantio
# Amantio      <--nmod      -- Nicolao
# di           <--nmod      -- Nicolao
# Nicolao      <--pobj      -- by
# (            <--punct     -- Pruitt
# Steven       <--compound  -- Pruitt
# Pruitt       <--appos     -- Nicolao
# )            <--punct     -- Pruitt
# who          <--nsubj     -- is
# as           <--prep      -- is
# of           <--prep      -- as
# that         <--det       -- date
# date         <--pobj      -- of
# is           <--relcl     -- Nicolao
# the          <--det       -- user
# user         <--attr      -- is
# with         <--prep      -- user
# the          <--det       -- number
# highest      <--amod      -- number
# number       <--pobj      -- with
# of           <--prep      -- number
# edits        <--pobj      -- of
# on           <--prep      -- edits
# the          <--det       -- Wikipedia
# English      <--compound  -- Wikipedia
# Wikipedia    <--pobj      -- on
# ,            <--punct     -- Nicolao
# at           <--prep      -- made
# over         <--quantmod  -- four
# four         <--nummod    -- million.[5
# million.[5   <--pobj      -- at
# ]            <--punct     -- made
# Currently    <--advmod    -- are
# ,            <--punct     -- are
# there        <--expl      -- are
# are          <--ROOT      -- are
# 7,107,928    <--nummod    -- articles
# articles     <--attr      -- are
# created      <--acl       -- articles
# with         <--prep      -- created
# 955,102      <--nummod    -- files
# files        <--pobj      -- with
# .            <--punct     -- are
# The          <--det       -- encyclopedia
# encyclopedia <--nsubj     -- is
# is           <--ROOT      -- is
# home         <--advmod    -- is
# to           <--prep      -- home
# 10.8         <--nummod    -- %
# %            <--pobj      -- to
# of           <--prep      -- %
# articles     <--pobj      -- of
# in           <--prep      -- articles
# all          <--det       -- Wikipedias
# Wikipedias   <--pobj      -- in
# (            <--punct     -- is
# down         <--advmod    -- is
# from         <--prep      -- down
# more         <--amod      -- 50
# than         <--quantmod  -- 50
# 50           <--nummod    -- %
# %            <--pobj      -- from
# in           <--prep      -- from
# 2003).[14][15 <--pobj      -- in
# ]            <--punct     -- is
# The          <--det       -- Wikipedia
# English      <--compound  -- Wikipedia
# Wikipedia    <--nsubj     -- has
# currently    <--advmod    -- has
# has          <--ROOT      -- has
# 50,685,466   <--nummod    -- accounts
# registered   <--amod      -- accounts
# accounts     <--dobj      -- has
# of           <--prep      -- are
# which        <--pobj      -- of
# 830          <--nsubj     -- are
# are          <--relcl     -- accounts
# administrators <--attr      -- are
# .            <--punct     -- has
#
#
#            <--dep       -- .
# Bureaucracy  <--compound  -- Editors
#
#             <--dep       -- Bureaucracy
# Editors      <--nsubj     -- pioneered
# of           <--prep      -- Editors
# the          <--det       -- Wikipedia
# English      <--compound  -- Wikipedia
# Wikipedia    <--pobj      -- of
# have         <--aux       -- pioneered
# pioneered    <--ROOT      -- pioneered
# some         <--det       -- ideas
# ideas        <--dobj      -- pioneered
# as           <--prep      -- ideas
# conventions  <--pobj      -- as
# ,            <--punct     -- conventions
# policies     <--conj      -- conventions
# or           <--cc        -- policies
# features     <--conj      -- policies
# which        <--nsubjpass -- adopted
# were         <--auxpass   -- adopted
# later        <--advmod    -- adopted
# adopted      <--relcl     -- policies
# by           <--agent     -- adopted
# Wikipedia    <--compound  -- editions
# editions     <--pobj      -- by
# in           <--prep      -- adopted
# some         <--pobj      -- in
# of           <--prep      -- some
# the          <--det       -- languages
# other        <--amod      -- languages
# languages    <--pobj      -- of
# .            <--punct     -- pioneered
# These        <--det       -- ideas
# ideas        <--nsubj     -- include
# include      <--ROOT      -- include
# "            <--punct     -- articles",[16
# featured     <--amod      -- articles",[16
# articles",[16 <--dobj      -- include
# ]            <--punct     -- include
# the          <--det       -- navigation
# neutral      <--amod      -- point
# -            <--punct     -- point
# point        <--nmod      -- policy,[17
# -            <--punct     -- point
# of           <--prep      -- point
# -            <--punct     -- of
# view         <--pobj      -- of
# policy,[17   <--nmod      -- navigation
# ]            <--punct     -- policy,[17
# navigation   <--dobj      -- include
# templates,[18 <--appos     -- navigation
# ]            <--punct     -- navigation
# the          <--det       -- sorting
# sorting      <--appos     -- navigation
# of           <--prep      -- sorting
# short        <--amod      -- articles
# "            <--punct     -- articles
# stub         <--nmod      -- articles
# "            <--punct     -- articles
# articles     <--pobj      -- of
# into         <--prep      -- sorting
# sub          <--nmod      -- mechanisms
# -            <--punct     -- sub
# categories,[19 <--nummod    -- dispute
# ]            <--punct     -- dispute
# dispute      <--compound  -- resolution
# resolution   <--compound  -- mechanisms
# mechanisms   <--pobj      -- into
# such         <--amod      -- as
# as           <--prep      -- mechanisms
# mediation    <--pobj      -- as
# and          <--cc        -- mediation
# arbitration,[20 <--conj      -- mediation
# ]            <--punct     -- sorting
# and          <--cc        -- sorting
# weekly       <--amod      -- article
# collaborations.[21 <--nmod      -- article
# ]            <--punct     -- collaborations.[21
#
#
#            <--dep       -- ]
# Wikipedians  <--amod      -- article
#
#             <--dep       -- Wikipedians
# Main         <--amod      -- article
# article      <--conj      -- sorting
# :            <--punct     -- include
# Wikipedian   <--compound  -- countries
#
#
#            <--dep       -- Wikipedian
# The          <--det       -- countries
# countries    <--nsubjpass -- shown
# in           <--prep      -- is
# which        <--pobj      -- in
# the          <--det       -- Wikipedia
# English      <--compound  -- Wikipedia
# Wikipedia    <--nsubj     -- is
# is           <--relcl     -- countries
# the          <--det       -- version
# most         <--advmod    -- popular
# popular      <--amod      -- version
# language     <--compound  -- version
# version      <--attr      -- is
# of           <--prep      -- version
# Wikipedia    <--pobj      -- of
# are          <--auxpass   -- shown
# shown        <--ccomp     -- include
# in           <--prep      -- shown
# red          <--pobj      -- in
# .            <--punct     -- shown
#
#
#            <--dep       -- .
# Number       <--nsubj     -- is
# of           <--prep      -- Number
# volunteer    <--compound  -- editors
# editors      <--pobj      -- of
# on           <--prep      -- Number
# the          <--det       -- Wikipedia
# English      <--compound  -- Wikipedia
# Wikipedia    <--pobj      -- on
# over         <--prep      -- Number
# time         <--compound  -- Edits
#
#
#            <--dep       -- time
# Edits        <--pobj      -- over
# to           <--prep      -- Edits
# English      <--compound  -- Wikipedia
# Wikipedia    <--pobj      -- to
# by           <--prep      -- Edits
# country      <--pobj      -- by
# as           <--prep      -- Number
# of           <--prep      -- as
# January      <--pobj      -- of
# 2022         <--nummod    -- January
#
#
#            <--dep       -- 2022
# The          <--det       -- Wikipedia
# English      <--compound  -- Wikipedia
# Wikipedia    <--pobj      -- as
# (            <--punct     -- marked
# marked       <--parataxis -- Wikipedia
# blue         <--dobj      -- marked
# in           <--prep      -- marked
# the          <--det       -- graph
# graph        <--pobj      -- in
# )            <--punct     -- marked
# is           <--ROOT      -- is
# the          <--det       -- version
# most         <--advmod    -- read
# -            <--punct     -- read
# read         <--amod      -- version
# version      <--attr      -- is
# of           <--prep      -- version
# Wikipedia    <--pobj      -- of
# ,            <--punct     -- is
# accounting   <--advcl     -- is
# for          <--prep      -- accounting
# 48           <--nummod    -- %
# %            <--pobj      -- for
# of           <--prep      -- %
# the          <--det       -- website
# website      <--poss      -- traffic
# 's           <--case      -- website
# global       <--amod      -- traffic
# traffic      <--pobj      -- of
# as           <--prep      -- accounting
# of           <--prep      -- as
# 2021         <--pobj      -- of
# .            <--punct     -- is
#
#
#            <--dep       -- .
# The          <--det       -- Wikipedia
# English      <--compound  -- Wikipedia
# Wikipedia    <--nsubj     -- been
# has          <--aux       -- been
# consistently <--advmod    -- been
# been         <--ROOT      -- been
# the          <--det       -- version
# most         <--advmod    -- edited
# edited       <--amod      -- version
# Wikipedia    <--compound  -- version
# language     <--compound  -- version
# version      <--attr      -- been
# .            <--punct     -- been
#
#             <--dep       -- .
# The          <--det       -- Wikipedia
# English      <--compound  -- Wikipedia
# Wikipedia    <--nsubj     -- reached
# reached      <--ROOT      -- reached
# 4,000,000    <--nummod    -- user
# registered   <--amod      -- user
# user         <--compound  -- accounts
# accounts     <--dobj      -- reached
# on           <--prep      -- accounts
# 1            <--nummod    -- April
# April        <--pobj      -- on
# 2007,[22     <--nummod    -- April
# ]            <--punct     -- accounts
# over         <--prep      -- reached
# a            <--det       -- year
# year         <--pobj      -- over
# since        <--mark      -- registered
# the          <--det       -- millionth
# millionth    <--pobj      -- since
# Wikipedian   <--nsubj     -- registered
# registered   <--advcl     -- reached
# an           <--det       -- account
# account      <--dobj      -- registered
# in           <--prep      -- registered
# February     <--pobj      -- in
# 2006.[23     <--nummod    -- February
# ]            <--punct     -- February
#
#
#            <--dep       -- ]
# Over         <--quantmod  -- 1,100,000
# 1,100,000    <--nummod    -- editors
# volunteer    <--compound  -- editors
# editors      <--nsubj     -- edited
# have         <--aux       -- edited
# edited       <--conj      -- registered
# Wikipedia    <--dobj      -- edited
# more         <--amod      -- 10
# than         <--quantmod  -- 10
# 10           <--nummod    -- times.[24
# times.[24    <--appos     -- Wikipedia
# ]            <--dep       -- perform
# Over         <--quantmod  -- 30,000
# 30,000       <--nummod    -- editors
# editors      <--nsubj     -- perform
# perform      <--ccomp     -- edited
# more         <--amod      -- 5
# than         <--quantmod  -- 5
# 5            <--nummod    -- edits
# edits        <--dobj      -- perform
# per          <--prep      -- edits
# month        <--pobj      -- per
# ,            <--punct     -- perform
# and          <--cc        -- perform
# over         <--quantmod  -- 3,000
# 3,000        <--nummod    -- perform
# perform      <--conj      -- perform
# more         <--amod      -- 100
# than         <--quantmod  -- 100
# 100          <--nummod    -- edits
# edits        <--dobj      -- perform
# per          <--prep      -- edits
# month.[25    <--pobj      -- per
# ]            <--punct     -- perform
#
#
#            <--dep       -- ]
# On           <--prep      -- reached
# 1            <--nummod    -- March
# March        <--pobj      -- On
# 2014         <--nummod    -- March
# ,            <--punct     -- reached
# The          <--det       -- Economist
# Economist    <--appos     -- accounts
# ,            <--punct     -- reached
# in           <--prep      -- reached
# an           <--det       -- article
# article      <--pobj      -- in
# titled       <--acl       -- article
# "            <--punct     -- Future
# The          <--det       -- Future
# Future       <--oprd      -- titled
# of           <--prep      -- Future
# Wikipedia    <--pobj      -- of
# "            <--punct     -- Future
# ,            <--punct     -- reached
# cited        <--conj      -- reached
# a            <--det       -- analysis
# trend        <--compound  -- analysis
# analysis     <--dobj      -- cited
# concerning   <--acl       -- analysis
# data         <--dobj      -- concerning
# published    <--acl       -- data
# by           <--agent     -- published
# the          <--det       -- Foundation
# Wikimedia    <--compound  -- Foundation
# Foundation   <--pobj      -- by
# stating      <--advcl     -- cited
# that         <--mark      -- fallen
# "            <--punct     -- fallen
# [            <--dep       -- fallen
# t]he         <--amod      -- number
# number       <--nsubj     -- fallen
# of           <--prep      -- number
# editors      <--pobj      -- of
# for          <--prep      -- number
# the          <--det       -- version
# English      <--compound  -- language
# -            <--punct     -- language
# language     <--compound  -- version
# version      <--pobj      -- for
# has          <--aux       -- fallen
# fallen       <--ccomp     -- stating
# by           <--prep      -- fallen
# a            <--det       -- third
# third        <--pobj      -- by
# in           <--prep      -- fallen
# seven        <--nummod    -- years
# years        <--pobj      -- in
# .            <--punct     -- reached
# "[26         <--punct     -- cited
# ]            <--dep       -- cited
# The          <--det       -- rate
# attrition    <--compound  -- rate
# rate         <--nsubjpass -- cited
# for          <--prep      -- rate
# active       <--amod      -- editors
# editors      <--pobj      -- for
# in           <--prep      -- editors
# English      <--compound  -- Wikipedia
# Wikipedia    <--pobj      -- in
# was          <--auxpass   -- cited
# cited        <--ROOT      -- cited
# by           <--agent     -- cited
# The          <--det       -- Economist
# Economist    <--pobj      -- by
# as           <--prep      -- cited
# substantially <--pcomp     -- as
# in           <--prep      -- cited
# contrast     <--pobj      -- in
# to           <--prep      -- contrast
# statistics   <--pobj      -- to
# for          <--prep      -- statistics
# Wikipedia    <--pobj      -- for
# in           <--prep      -- statistics
# other        <--amod      -- languages
# languages    <--pobj      -- in
# (            <--punct     -- languages
# non          <--amod      -- Wikipedia
# -            <--amod      -- Wikipedia
# English      <--amod      -- Wikipedia
# Wikipedia    <--appos     -- languages
# )            <--punct     -- cited
# .            <--punct     -- cited
# The          <--det       -- Economist
# Economist    <--nsubj     -- reported
# reported     <--ROOT      -- reported
# that         <--mark      -- was
# the          <--det       -- number
# number       <--nsubj     -- was
# of           <--prep      -- number
# contributors <--pobj      -- of
# with         <--prep      -- contributors
# an           <--det       -- average
# average      <--pobj      -- with
# of           <--prep      -- average
# five         <--nummod    -- edits
# or           <--cc        -- five
# more         <--conj      -- five
# edits        <--pobj      -- of
# per          <--prep      -- edits
# month        <--pobj      -- per
# was          <--ccomp     -- reported
# relatively   <--advmod    -- constant
# constant     <--acomp     -- was
# since        <--prep      -- was
# 2008         <--pobj      -- since
# for          <--prep      -- was
# Wikipedia    <--pobj      -- for
# in           <--prep      -- was
# other        <--amod      -- languages
# languages    <--pobj      -- in
# at           <--prep      -- was
# approximately <--advmod    -- 42,000
# 42,000       <--nummod    -- editors
# editors      <--pobj      -- at
# within       <--prep      -- was
# narrow       <--amod      -- variances
# seasonal     <--amod      -- variances
# variances    <--pobj      -- within
# of           <--prep      -- variances
# about        <--advmod    -- 2,000
# 2,000        <--nummod    -- editors
# editors      <--pobj      -- of
# up           <--advmod    -- was
# or           <--cc        -- up
# down         <--conj      -- up
# .            <--punct     -- reported
# The          <--det       -- number
# number       <--nsubjpass -- cited
# of           <--prep      -- number
# active       <--amod      -- editors
# editors      <--pobj      -- of
# in           <--prep      -- number
# English      <--compound  -- Wikipedia
# Wikipedia    <--pobj      -- in
# ,            <--punct     -- number
# by           <--prep      -- number
# "            <--punct     -- comparison
# sharp        <--amod      -- comparison
# "            <--punct     -- comparison
# comparison   <--pobj      -- by
# ,            <--punct     -- cited
# was          <--auxpass   -- cited
# cited        <--ROOT      -- cited
# as           <--prep      -- cited
# peaking      <--pcomp     -- as
# in           <--prep      -- peaking
# 2007         <--pobj      -- in
# at           <--prep      -- peaking
# approximately <--advmod    -- 50,000
# 50,000       <--pobj      -- at
# and          <--cc        -- peaking
# dropping     <--conj      -- peaking
# to           <--prep      -- dropping
# 30,000       <--pobj      -- to
# by           <--prep      -- dropping
# the          <--det       -- start
# start        <--pobj      -- by
# of           <--prep      -- start
# 2014         <--pobj      -- of
# .            <--punct     -- cited
#
#
#            <--dep       -- .
# The          <--det       -- analysis
# trend        <--compound  -- analysis
# analysis     <--nsubj     -- presents
# published    <--acl       -- analysis
# in           <--prep      -- published
# The          <--det       -- Economist
# Economist    <--pobj      -- in
# presents     <--ROOT      -- presents
# Wikipedia    <--dobj      -- presents
# in           <--prep      -- presents
# other        <--amod      -- languages
# languages    <--pobj      -- in
# (            <--punct     -- languages
# non          <--amod      -- Wikipedia
# -            <--amod      -- Wikipedia
# English      <--amod      -- Wikipedia
# Wikipedia    <--appos     -- languages
# )            <--punct     -- languages
# as           <--advmod    -- successful
# successful   <--advcl     -- presents
# in           <--prep      -- successful
# retaining    <--pcomp     -- in
# their        <--poss      -- editors
# active       <--amod      -- editors
# editors      <--dobj      -- retaining
# on           <--prep      -- retaining
# a            <--det       -- basis
# renewable    <--amod      -- basis
# and          <--cc        -- renewable
# sustained    <--conj      -- renewable
# basis        <--pobj      -- on
# ,            <--punct     -- presents
# with         <--prep      -- presents
# their        <--poss      -- numbers
# numbers      <--nsubj     -- remaining
# remaining    <--pcomp     -- with
# relatively   <--advmod    -- constant
# constant     <--acomp     -- remaining
# at           <--prep      -- remaining
# approximately <--advmod    -- 42,000.[26
# 42,000.[26   <--pobj      -- at
# ]            <--punct     -- presents
#
#
#            <--dep       -- ]
# The          <--det       -- Wikipedia
# English      <--compound  -- Wikipedia
# Wikipedia    <--nsubj     -- has
# has          <--ccomp     -- presents
# the          <--det       -- Committee
# Arbitration  <--compound  -- Committee
# Committee    <--dobj      -- has
# (            <--punct     -- Committee
# also         <--advmod    -- known
# known        <--acl       -- Committee
# as           <--prep      -- known
# ArbCom       <--pobj      -- as
# )            <--punct     -- Committee
# that         <--nsubj     -- consists
# consists     <--relcl     -- Committee
# of           <--prep      -- consists
# a            <--det       -- panel
# panel        <--pobj      -- of
# of           <--prep      -- panel
# editors      <--pobj      -- of
# that         <--nsubj     -- imposes
# imposes      <--relcl     -- panel
# binding      <--amod      -- rulings
# rulings      <--dobj      -- imposes
# with         <--prep      -- imposes
# regard       <--pobj      -- with
# to           <--prep      -- regard
# disputes     <--pobj      -- to
# between      <--prep      -- disputes
# other        <--amod      -- editors
# editors      <--pobj      -- between
# of           <--prep      -- editors
# the          <--det       -- encyclopedia.[27
# online       <--amod      -- encyclopedia.[27
# encyclopedia.[27 <--pobj      -- of
# ]            <--punct     -- has
# It           <--nsubjpass -- created
# was          <--auxpass   -- created
# created      <--ccomp     -- consisted
# by           <--agent     -- created
# Jimmy        <--compound  -- Wales
# Wales        <--pobj      -- by
# on           <--prep      -- created
# 4            <--nummod    -- December
# December     <--pobj      -- on
# 2003         <--nummod    -- December
# as           <--prep      -- created
# an           <--det       -- extension
# extension    <--pobj      -- as
# of           <--prep      -- extension
# the          <--det       -- power
# decision     <--npadvmod  -- making
# -            <--punct     -- making
# making       <--amod      -- power
# power        <--pobj      -- of
# he           <--nsubj     -- held
# had          <--aux       -- held
# formerly     <--advmod    -- held
# held         <--relcl     -- power
# as           <--prep      -- held
# owner        <--pobj      -- as
# of           <--prep      -- owner
# the          <--det       -- site.[28][29
# site.[28][29 <--pobj      -- of
# ]            <--punct     -- created
# When         <--advmod    -- founded
# it           <--nsubjpass -- founded
# was          <--auxpass   -- founded
# founded      <--advcl     -- consisted
# ,            <--punct     -- consisted
# the          <--det       -- committee
# committee    <--nsubj     -- consisted
# consisted    <--ccomp     -- accounted
# of           <--prep      -- consisted
# 12           <--nummod    -- arbitrators
# arbitrators  <--pobj      -- of
# divided      <--acl       -- arbitrators
# into         <--prep      -- divided
# three        <--nummod    -- groups
# groups       <--pobj      -- into
# of           <--prep      -- groups
# four         <--nummod    -- members
# members      <--pobj      -- of
# each.[28][30 <--dobj      -- consisted
# ]            <--punct     -- each.[28][30
#
#
#            <--dep       -- ]
# In           <--prep      -- consisted
# 2022         <--pobj      -- In
# ,            <--punct     -- consisted
# for          <--prep      -- consisted
# English      <--compound  -- Wikipedia
# Wikipedia    <--pobj      -- for
# ,            <--punct     -- accounted
# Americans    <--nsubj     -- accounted
# accounted    <--ccomp     -- is
# for          <--prep      -- accounted
# about        <--advmod    -- 40
# 40           <--nummod    -- %
# %            <--pobj      -- for
# of           <--prep      -- %
# active       <--amod      -- editors
# editors      <--pobj      -- of
# ,            <--punct     -- accounted
# followed     <--advcl     -- accounted
# by           <--agent     -- followed
# British      <--amod      -- editors
# and          <--cc        -- British
# Indian       <--conj      -- British
# editors      <--pobj      -- by
# accounting   <--acl       -- editors
# for          <--prep      -- accounting
# about        <--advmod    -- 10
# 10           <--nummod    -- %
# %            <--pobj      -- for
# of           <--prep      -- %
# each         <--pobj      -- of
# ,            <--punct     -- followed
# and          <--cc        -- followed
# Canadian     <--conj      -- followed
# and          <--cc        -- Canadian
# Australian   <--conj      -- Canadian
# at           <--prep      -- followed
# about        <--advmod    -- 5%.[31
# 5%.[31       <--pobj      -- at
# ]            <--punct     -- followed
#
#
#            <--dep       -- ]
# Criticism    <--dobj      -- followed
#
#
#            <--dep       -- Criticism
# Two          <--nummod    -- versions
# radically    <--advmod    -- different
# different    <--amod      -- versions
# versions     <--dobj      -- Criticism
# of           <--prep      -- versions
# the          <--det       -- biography
# Wikipedia    <--compound  -- biography
# biography    <--compound  -- Irwin
# Klee         <--compound  -- Irwin
# Irwin        <--pobj      -- of
# (            <--punct     -- Irwin
# now          <--advmod    -- deleted)[32
# deleted)[32  <--appos     -- Irwin
# ]            <--punct     -- Irwin
# presented    <--acl       -- Criticism
# to           <--prep      -- presented
# the          <--det       -- public
# public       <--pobj      -- to
# within       <--prep      -- presented
# days         <--pobj      -- within
# of           <--prep      -- days
# each         <--det       -- other
# other        <--pobj      -- of
# :            <--punct     -- is
# Wikipedia    <--poss      -- susceptibility
# 's           <--case      -- Wikipedia
# susceptibility <--nsubj     -- is
# to           <--aux       -- edit
# edit         <--acl       -- susceptibility
# wars         <--dobj      -- edit
# and          <--cc        -- wars
# bias         <--conj      -- wars
# is           <--ROOT      -- is
# an           <--det       -- issue
# issue        <--attr      -- is
# often        <--advmod    -- raised
# raised       <--acl       -- issue
# by           <--agent     -- raised
# the          <--det       -- project
# project      <--poss      -- critics
# 's           <--case      -- project
# critics      <--pobj      -- by
# .            <--punct     -- is
#
#             <--dep       -- .
# The          <--det       -- Wikipedia
# free         <--amod      -- encyclopedia
# online       <--amod      -- encyclopedia
# encyclopedia <--compound  -- Wikipedia
# Wikipedia    <--nsubjpass -- criticized
# has          <--aux       -- criticized
# been         <--auxpass   -- criticized
# criticized   <--ROOT      -- criticized
# since        <--prep      -- criticized
# its          <--poss      -- creation
# creation     <--pobj      -- since
# in           <--prep      -- criticized
# 2001         <--pobj      -- in
# .            <--punct     -- criticized
# Most         <--nsubjpass -- directed
# of           <--prep      -- Most
# the          <--det       -- criticism
# criticism    <--pobj      -- of
# has          <--aux       -- directed
# been         <--auxpass   -- directed
# directed     <--ROOT      -- directed
# toward       <--prep      -- directed
# its          <--poss      -- content
# content      <--pobj      -- toward
# ,            <--punct     -- content
# community    <--appos     -- content
# of           <--prep      -- community
# established  <--amod      -- users
# volunteer    <--compound  -- users
# users        <--pobj      -- of
# ,            <--punct     -- users
# process      <--conj      -- users
# ,            <--punct     -- process
# and          <--cc        -- process
# rules        <--conj      -- process
# .            <--punct     -- directed
# Critics      <--nsubj     -- questioned
# have         <--aux       -- questioned
# questioned   <--ROOT      -- questioned
# its          <--poss      -- reliability
# factual      <--amod      -- reliability
# reliability  <--dobj      -- questioned
# ,            <--punct     -- reliability
# the          <--det       -- readability
# readability  <--conj      -- reliability
# and          <--cc        -- readability
# organization <--conj      -- readability
# of           <--prep      -- readability
# its          <--poss      -- articles
# articles     <--pobj      -- of
# ,            <--punct     -- readability
# the          <--det       -- lack
# lack         <--conj      -- readability
# of           <--prep      -- lack
# methodical   <--amod      -- checking
# fact         <--compound  -- checking
# -            <--punct     -- checking
# checking     <--pobj      -- of
# ,            <--punct     -- lack
# and          <--cc        -- lack
# its          <--poss      -- bias
# political    <--amod      -- bias
# bias         <--conj      -- lack
# .            <--punct     -- questioned
#
#
#            <--dep       -- .
# Concerns     <--nsubjpass -- raised
# have         <--aux       -- raised
# also         <--advmod    -- raised
# been         <--auxpass   -- raised
# raised       <--ROOT      -- raised
# about        <--prep      -- raised
# systemic     <--amod      -- bias
# bias         <--pobj      -- about
# along        <--prep      -- bias
# gender       <--pobj      -- along
# ,            <--punct     -- gender
# racial       <--amod      -- lines
# ,            <--punct     -- lines
# political    <--amod      -- lines
# ,            <--punct     -- lines
# corporate    <--amod      -- lines
# ,            <--punct     -- institutional
# institutional <--conj      -- corporate
# ,            <--punct     -- institutional
# and          <--cc        -- institutional
# national     <--conj      -- institutional
# lines        <--appos     -- gender
# .            <--punct     -- raised
# Conflicts    <--nsubjpass -- highlighted
# of           <--prep      -- Conflicts
# interest     <--pobj      -- of
# arising      <--acl       -- interest
# from         <--prep      -- arising
# corporate    <--amod      -- campaigns
# campaigns    <--pobj      -- from
# to           <--prep      -- from
# influence    <--compound  -- content
# ...
# with         <--prep      -- begins
# "            <--punct     -- Stub
# Stub         <--pobj      -- with
# "            <--punct     -- Stub
# (            <--punct     -- Stub
# very         <--advmod    -- short
# short        <--amod      -- pages
# pages        <--appos     -- Stub
# )            <--punct     -- Stub
# ,            <--punct     -- begins
# followed     <--advcl     -- begins
# by           <--agent     -- followed
# "            <--punct     -- Start
# Start        <--pobj      -- by
# "            <--punct     -- Start
# ,            <--punct     -- Start
# "            <--punct     -- C
# C            <--conj      -- Start
# "            <--punct     -- C
# and          <--cc        -- C
# "            <--punct     -- B
# B            <--conj      -- C
# "            <--punct     -- B
# (            <--punct     -- Start
# in           <--prep      -- followed
# increasing   <--amod      -- order
# order        <--pobj      -- in
# of           <--prep      -- order
# quality      <--pobj      -- of
# )            <--punct     -- followed
# .            <--punct     -- begins
# Community    <--amod      -- review
# peer         <--compound  -- review
# review       <--nsubjpass -- needed
# is           <--auxpass   -- needed
# needed       <--ROOT      -- needed
# for          <--mark      -- enter
# the          <--det       -- article
# article      <--nsubj     -- enter
# to           <--aux       -- enter
# enter        <--advcl     -- needed
# one          <--dobj      -- enter
# of           <--prep      -- one
# the          <--det       -- classes
# quality      <--compound  -- classes
# classes      <--pobj      -- of
# :            <--punct     -- needed
# either       <--preconj   -- article
# "            <--punct     -- article
# good         <--amod      -- article
# article      <--appos     -- review
# "            <--punct     -- article
# ,            <--punct     -- article
# "            <--punct     -- A
# A            <--appos     -- article
# "            <--punct     -- A
# or           <--cc        -- A
# the          <--det       -- article
# highest      <--amod      -- article
# ,            <--punct     -- article
# "            <--punct     -- article
# featured     <--amod      -- article
# article      <--conj      -- A
# "            <--punct     -- article
# .            <--punct     -- needed
# Of           <--prep      -- are
# the          <--det       -- articles
# about        <--quantmod  -- million
# 6.5          <--compound  -- million
# million      <--nummod    -- articles
# articles     <--pobj      -- Of
# and          <--cc        -- articles
# lists        <--conj      -- articles
# assessed     <--acl       -- articles
# as           <--prep      -- assessed
# of           <--prep      -- as
# April        <--pobj      -- of
# 2022         <--nummod    -- April
# ,            <--punct     -- are
# more         <--amod      -- 6,000
# than         <--quantmod  -- 6,000
# 6,000        <--nsubj     -- are
# (            <--punct     -- 6,000
# 0.09         <--nummod    -- %
# %            <--appos     -- 6,000
# )            <--punct     -- 6,000
# are          <--auxpass   -- featured
# featured     <--amod      -- articles
# articles     <--nsubj     -- are
# ,            <--punct     -- articles
# and          <--cc        -- articles
# fewer        <--amod      -- 4,000
# than         <--quantmod  -- 4,000
# 4,000        <--conj      -- articles
# (            <--punct     -- 4,000
# 0.06         <--nummod    -- %
# %            <--appos     -- 4,000
# )            <--punct     -- 4,000
# are          <--ROOT      -- are
# featured     <--amod      -- lists
# lists        <--attr      -- are
# .            <--punct     -- are
# One          <--nummod    -- article
# featured     <--amod      -- article
# article      <--nsubj     -- appears
# per          <--prep      -- article
# day          <--pobj      -- per
# ,            <--punct     -- article
# as           <--mark      -- selected
# selected     <--advcl     -- article
# by           <--agent     -- selected
# editors      <--pobj      -- by
# ,            <--punct     -- article
# appears      <--ROOT      -- appears
# on           <--prep      -- appears
# the          <--det       -- page
# main         <--amod      -- page
# page         <--pobj      -- on
# of           <--prep      -- page
# Wikipedia.[44][45 <--pobj      -- of
# ]            <--pobj      -- of
#
#
#            <--dep       -- ]
# Researcher   <--compound  -- Giacomo
# Giacomo      <--compound  -- Poderi
# Poderi       <--pobj      -- of
# found        <--advcl     -- appears
# that         <--mark      -- tend
# articles     <--nsubj     -- tend
# tend         <--ccomp     -- found
# to           <--aux       -- reach
# reach        <--xcomp     -- tend
# featured     <--amod      -- status
# status       <--dobj      -- reach
# via          <--prep      -- reach
# the          <--det       -- work
# intensive    <--amod      -- work
# work         <--pobj      -- via
# of           <--prep      -- work
# a            <--det       -- editors.[46
# few          <--amod      -- editors.[46
# editors.[46  <--pobj      -- of
# ]            <--dep       -- tend
# A            <--det       -- study
# 2010         <--nummod    -- study
# study        <--nsubj     -- found
# found        <--ccomp     -- tend
# unevenness   <--oprd      -- found
# in           <--prep      -- found
# quality      <--pobj      -- in
# among        <--prep      -- found
# featured     <--amod      -- articles
# articles     <--pobj      -- among
# and          <--cc        -- found
# concluded    <--conj      -- found
# that         <--mark      -- is
# the          <--det       -- process
# community    <--compound  -- process
# process      <--nsubj     -- is
# is           <--ccomp     -- concluded
# ineffective  <--acomp     -- is
# in           <--prep      -- ineffective
# assessing    <--pcomp     -- in
# the          <--det       -- quality
# quality      <--dobj      -- assessing
# of           <--prep      -- quality
# articles.[47 <--pobj      -- of
# ]            <--punct     -- of
#
#
#            <--dep       -- ]
# Internal     <--amod      -- news
# news         <--compound  -- publications
# publications <--pobj      -- of
#
#
#            <--dep       -- publications
# The          <--det       -- icon
# Signpost     <--compound  -- icon
# icon         <--pobj      -- of
# ,            <--punct     -- assessing
# showing      <--advcl     -- assessing
# a            <--det       -- publications
# styled       <--amod      -- publications
# 'S           <--nmod      -- publications
# '            <--punct     -- publications
#
#             <--dep       -- '
# Community    <--npadvmod  -- produced
# -            <--punct     -- produced
# produced     <--amod      -- publications
# news         <--compound  -- publications
# publications <--nsubj     -- include
# include      <--ccomp     -- showing
# The          <--det       -- Signpost.[48
# Signpost.[48 <--dobj      -- include
# ]            <--punct     -- Signpost.[48
# Other        <--amod      -- publications
# community    <--compound  -- publications
# news         <--compound  -- publications
# publications <--nsubj     -- include
# include      <--relcl     -- Signpost.[48
# the          <--det       -- comic
# "            <--punct     -- comic
# WikiWorld    <--nmod      -- web
# "            <--punct     -- web
# web          <--compound  -- comic
# comic        <--dobj      -- include
# ,            <--punct     -- comic
# the          <--det       -- podcast
# Wikipedia    <--compound  -- podcast
# Weekly       <--compound  -- podcast
# podcast      <--conj      -- comic
# ,            <--punct     -- comic
# and          <--cc        -- comic
# newsletters  <--conj      -- comic
# of           <--prep      -- newsletters
# specific     <--amod      -- WikiProjects
# WikiProjects <--pobj      -- of
# like         <--prep      -- WikiProjects
# The          <--det       -- Bugle
# Bugle        <--pobj      -- like
# from         <--prep      -- Bugle
# WikiProject  <--compound  -- History
# Military     <--compound  -- History
# History      <--pobj      -- from
# and          <--cc        -- History
# the          <--det       -- newsletter
# monthly      <--amod      -- newsletter
# newsletter   <--conj      -- History
# from         <--prep      -- newsletter
# The          <--det       -- Guild
# Guild        <--pobj      -- from
# of           <--prep      -- Guild
# Copy         <--compound  -- Editors
# Editors      <--pobj      -- of
# .            <--punct     -- appears
# There        <--expl      -- are
# are          <--ROOT      -- are
# a            <--det       -- number
# number       <--attr      -- are
# of           <--prep      -- number
# publications <--pobj      -- of
# from         <--prep      -- publications
# the          <--det       -- Foundation
# Wikimedia    <--compound  -- Foundation
# Foundation   <--pobj      -- from
# and          <--cc        -- Foundation
# multilingual <--amod      -- publications
# publications <--conj      -- Foundation
# such         <--amod      -- as
# as           <--prep      -- publications
# the          <--det       -- Blog
# Wikimedia    <--compound  -- Blog
# Blog         <--pobj      -- as
# and          <--cc        -- Blog
# This         <--det       -- Month
# Month        <--conj      -- Blog
# in           <--prep      -- Month
# Education    <--pobj      -- in
# .            <--punct     -- are
#
#
#            <--dep       -- .
# See          <--advcl     -- is
# also         <--advmod    -- views
#
#
#            <--dep       -- also
# Wikipedia    <--compound  -- page
# page         <--compound  -- views
# views        <--dobj      -- See
# by           <--prep      -- views
# language     <--compound  -- Notes
#
#             <--dep       -- language
# English      <--compound  -- Wikipedia
# Wikipedia    <--compound  -- blackout
# blackout     <--compound  -- Notes
#
#             <--dep       -- blackout
# Deletionpedia <--compound  -- Notes
#
#             <--dep       -- Deletionpedia
# Notes        <--pobj      -- by
#
#             <--dep       -- Notes
# The          <--det       -- edition
# other        <--amod      -- edition
# edition      <--nsubj     -- is
# is           <--ROOT      -- is
# Simple       <--compound  -- Wikipedia
# English      <--compound  -- Wikipedia
# Wikipedia    <--attr      -- is
# ,            <--punct     -- Wikipedia
# which        <--nsubj     -- uses
# uses         <--relcl     -- Wikipedia
# Basic        <--compound  -- English
# English      <--dobj      -- uses
# .            <--punct     -- is
#
#             <--dep       -- .
# The          <--det       -- number
# number       <--nsubjpass -- shown
# of           <--prep      -- number
# articles     <--pobj      -- of
# on           <--prep      -- articles
# the          <--det       -- Wikipedia
# English      <--compound  -- Wikipedia
# Wikipedia    <--pobj      -- on
# is           <--auxpass   -- shown
# shown        <--ROOT      -- shown
# by           <--agent     -- shown
# the          <--det       -- variable
# MediaWiki    <--compound  -- variable
# variable     <--pobj      -- by
# {            <--punct     -- variable
# {            <--punct     -- variable
# NUMBEROFARTICLES <--appos     -- variable
# }            <--punct     -- variable
# }            <--punct     -- shown
# ,            <--punct     -- shown
# with         <--prep      -- shown
# all          <--det       -- Wikipedias
# Wikipedias   <--pobj      -- with
# as           <--prep      -- Wikipedias
# total        <--pobj      -- as
# {            <--punct     -- NUMBEROF|ARTICLES|total
# {            <--punct     -- NUMBEROF|ARTICLES|total
# NUMBEROF|ARTICLES|total <--appos     -- Wikipedias
# }            <--punct     -- Wikipedias
# }            <--punct     -- shown
# =            <--prep      -- shown
# 66,118,901   <--npadvmod  -- =
# .            <--punct     -- shown
#
#             <--dep       -- .
# Despite      <--prep      -- recognize
# this         <--det       -- praise
# praise       <--pobj      -- Despite
# ,            <--punct     -- recognize
# Wikipedia    <--nsubj     -- recognize
# does         <--aux       -- recognize
# not          <--neg       -- recognize
# recognize    <--ROOT      -- recognize
# itself       <--dobj      -- recognize
# as           <--prep      -- recognize
# a            <--det       -- source
# reliable     <--amod      -- source
# source       <--pobj      -- as
# .            <--punct     -- recognize
#
#             <--dep       -- .
# References   <--compound  -- Harrison
#
#             <--dep       -- References
# Harrison     <--ROOT      -- Harrison
# ,            <--punct     -- Harrison
# Stephen      <--appos     -- Harrison
# (            <--punct     -- Stephen
# 1            <--appos     -- Stephen
# September    <--appos     -- Stephen
# 2021         <--nummod    -- September
# )            <--punct     -- Stephen
# .            <--punct     -- Harrison
# "            <--punct     -- Trying
# Wikipedia    <--nsubj     -- Trying
# Is           <--aux       -- Trying
# Trying       <--ROOT      -- Trying
# to           <--aux       -- Transcend
# Transcend    <--xcomp     -- Trying
# the          <--det       -- Limits
# Limits       <--dobj      -- Transcend
# of           <--prep      -- Limits
# Human        <--compound  -- Language
# Language     <--pobj      -- of
# "            <--punct     -- Transcend
# .            <--punct     -- Trying
# Slate        <--ROOT      -- Slate
# .            <--punct     -- Slate
# Archived     <--ROOT      -- Archived
# from         <--prep      -- Archived
# the          <--det       -- original
# original     <--pobj      -- from
# on           <--prep      -- Archived
# 30           <--nummod    -- July
# July         <--pobj      -- on
# 2023         <--nummod    -- July
# .            <--punct     -- Archived
# Retrieved    <--ROOT      -- Retrieved
# 17           <--dobj      -- Retrieved
# October      <--npadvmod  -- Retrieved
# 2023         <--nummod    -- October
# .            <--punct     -- Retrieved
#
#             <--dep       -- .
# Sato         <--ROOT      -- Sato
# ,            <--punct     -- Sato
# Yumiko       <--appos     -- Sato
# (            <--punct     -- Yumiko
# 19           <--nummod    -- March
# March        <--npadvmod  -- Yumiko
# 2021         <--nummod    -- March
# )            <--punct     -- Yumiko
# .            <--punct     -- Sato
# "            <--punct     -- Have
# Non          <--compound  -- Editions
# -            <--amod      -- Editions
# English      <--amod      -- Editions
# Editions     <--nsubj     -- Have
# of           <--prep      -- Editions
# Wikipedia    <--pobj      -- of
# Have         <--ROOT      -- Have
# a            <--det       -- Problem
# Misinformation <--compound  -- Problem
# Problem      <--dobj      -- Have
# "            <--punct     -- Have
# .            <--punct     -- Have
# Slate        <--ROOT      -- Slate
# .            <--punct     -- Slate
# Archived     <--ROOT      -- Archived
# from         <--prep      -- Archived
# the          <--det       -- original
# original     <--pobj      -- from
# on           <--prep      -- Archived
# 25           <--nummod    -- August
# August       <--pobj      -- on
# 2023         <--nummod    -- August
# .            <--punct     -- Archived
# Retrieved    <--ROOT      -- Retrieved
# 17           <--dobj      -- Retrieved
# October      <--npadvmod  -- Retrieved
# 2023         <--nummod    -- October
# .            <--punct     -- Retrieved
#
#             <--dep       -- .
# Anderson     <--ROOT      -- Anderson
# ,            <--punct     -- Anderson
# Monica       <--npadvmod  -- Anderson
# ;            <--punct     -- Anderson
# Hitlin       <--conj      -- Anderson
# ,            <--punct     -- Hitlin
# Paul         <--conj      -- Hitlin
# ;            <--punct     -- Paul
# Atkinson     <--conj      -- Paul
# ,            <--punct     -- Atkinson
# Michelle     <--conj      -- Atkinson
# (            <--punct     -- Michelle
# 14           <--punct     -- Anderson
# January      <--npadvmod  -- Anderson
# 2016         <--nummod    -- January
# )            <--punct     -- Anderson
# .            <--punct     -- Anderson
# "            <--punct     -- Wikipedia
# Wikipedia    <--ROOT      -- Wikipedia
# at           <--prep      -- Wikipedia
# 15           <--pobj      -- at
# :            <--punct     -- Millions
# Millions     <--appos     -- Wikipedia
# of           <--prep      -- Millions
# readers      <--pobj      -- of
# in           <--prep      -- Millions
#
#             <--dep       -- in

# %% [markdown]
# #Sentence wise grammar parsing

# %%
for sent in doc.sents:
    print("Sentence:", sent.text)
    for token in sent:
        print(f"  {token.text:15} {token.pos_:10} {token.dep_:10} --> {token.head.text}")
    print()
# Out:
# Sentence:
# "en.wikipedia.org" redirects here.
#
#                SPACE      dep        --> redirects
#   "               PUNCT      punct      --> redirects
#   en.wikipedia.org PROPN      amod       --> redirects
#   "               PUNCT      punct      --> redirects
#   redirects       NOUN       ROOT       --> redirects
#   here            ADV        advmod     --> redirects
#   .               PUNCT      punct      --> redirects
#
# Sentence: For the main page, see Main Page.
#   For             ADP        prep       --> see
#   the             DET        det        --> page
#   main            ADJ        amod       --> page
#   page            NOUN       pobj       --> For
#   ,               PUNCT      punct      --> see
#   see             VERB       ROOT       --> see
#   Main            PROPN      compound   --> Page
#   Page            PROPN      dobj       --> see
#   .               PUNCT      punct      --> see
#
# Sentence: For the version of Wikipedia written in Basic English, see Simple English Wikipedia.
#
#   For             ADP        prep       --> see
#   the             DET        det        --> version
#   version         NOUN       pobj       --> For
#   of              ADP        prep       --> version
#   Wikipedia       PROPN      pobj       --> of
#   written         VERB       acl        --> version
#   in              ADP        prep       --> written
#   Basic           PROPN      compound   --> English
#   English         PROPN      pobj       --> in
#   ,               PUNCT      punct      --> see
#   see             VERB       ROOT       --> see
#   Simple          PROPN      compound   --> Wikipedia
#   English         PROPN      compound   --> Wikipedia
#   Wikipedia       PROPN      nsubj      --> see
#   .               PUNCT      punct      --> see
#
#                SPACE      dep        --> .
#
# Sentence: Favicon of Wikipedia English Wikipedia
# Wikipedia logo with text: WIKIPEDIA The Free Encyclopedia
# Screenshot
# Type of site	Online encyclopedia
# Available in	English
# Owner	Wikimedia Foundation
# Founder(s)	Jimmy Wales
# Larry Sanger
# Editors	English Wikipedia community
# URL	en.wikipedia.org Edit this at Wikidata
# Commercial	No
# Registration	Optional; required for certain tasks
# Users	50.7 million (as of 19 December 2025)
#
#   Favicon         PROPN      nmod       --> Edit
#   of              ADP        prep       --> Favicon
#   Wikipedia       PROPN      compound   --> Wikipedia
#   English         PROPN      compound   --> Wikipedia
#   Wikipedia       PROPN      compound   --> Wikipedia
#
#                SPACE      dep        --> Wikipedia
#   Wikipedia       PROPN      compound   --> logo
#   logo            NOUN       pobj       --> of
#   with            ADP        prep       --> logo
#   text            NOUN       pobj       --> with
#   :               PUNCT      punct      --> Favicon
#   WIKIPEDIA       PROPN      appos      --> Favicon
#   The             DET        det        --> Type
#   Free            ADJ        amod       --> Type
#   Encyclopedia    PROPN      compound   --> Type
#
#                SPACE      dep        --> Encyclopedia
#   Screenshot      PROPN      compound   --> Type
#
#                SPACE      dep        --> Screenshot
#   Type            PROPN      appos      --> WIKIPEDIA
#   of              ADP        prep       --> Type
#   site            NOUN       compound   --> encyclopedia
#   	               SPACE      dep        --> site
#   Online          ADJ        amod       --> encyclopedia
#   encyclopedia    NOUN       pobj       --> of
#
#                SPACE      dep        --> encyclopedia
#   Available       PROPN      amod       --> WIKIPEDIA
#   in              ADP        prep       --> Available
#   	               SPACE      dep        --> in
#   English         PROPN      compound   --> Founder(s
#
#                SPACE      dep        --> English
#   Owner           PROPN      compound   --> Founder(s
#   	               SPACE      dep        --> Owner
#   Wikimedia       PROPN      compound   --> Founder(s
#   Foundation      PROPN      compound   --> Founder(s
#
#                SPACE      dep        --> Foundation
#   Founder(s       NOUN       pobj       --> in
#   )               PUNCT      punct      --> WIKIPEDIA
#   	               SPACE      dep        --> )
#   Jimmy           PROPN      compound   --> Wales
#   Wales           PROPN      compound   --> Sanger
#
#                SPACE      dep        --> Wales
#   Larry           PROPN      compound   --> Sanger
#   Sanger          PROPN      nmod       --> Edit
#
#                SPACE      dep        --> Sanger
#   Editors         NOUN       appos      --> Sanger
#   	               SPACE      dep        --> Editors
#   English         PROPN      compound   --> Wikipedia
#   Wikipedia       PROPN      appos      --> Editors
#   community       NOUN       compound   --> URL
#
#                SPACE      dep        --> community
#   URL             PROPN      compound   --> Edit
#   	               SPACE      dep        --> URL
#   en.wikipedia.org PROPN      compound   --> Edit
#   Edit            PROPN      ROOT       --> Edit
#   this            PRON       dobj       --> Edit
#   at              ADP        prep       --> Edit
#   Wikidata        PROPN      compound   --> Optional
#
#                SPACE      dep        --> Wikidata
#   Commercial      PROPN      compound   --> Optional
#   	               SPACE      dep        --> Commercial
#   No              PROPN      compound   --> Optional
#
#                SPACE      dep        --> No
#   Registration    PROPN      compound   --> Optional
#   	               SPACE      dep        --> Registration
#   Optional        PROPN      pobj       --> at
#   ;               PUNCT      punct      --> Edit
#   required        VERB       acl        --> Edit
#   for             ADP        prep       --> required
#   certain         ADJ        amod       --> tasks
#   tasks           NOUN       pobj       --> for
#
#                SPACE      dep        --> tasks
#   Users           NOUN       compound   --> million
#   	               SPACE      dep        --> Users
#   50.7            NUM        compound   --> million
#   million         NUM        appos      --> tasks
#   (               PUNCT      punct      --> million
#   as              ADP        prep       --> required
#   of              ADP        prep       --> as
#   19              NUM        pobj       --> of
#   December        PROPN      pobj       --> of
#   2025            NUM        nummod     --> December
#   )               PUNCT      punct      --> required
#
#                SPACE      dep        --> )
#
# Sentence: Launched	15 January 2001; 24 years ago
# Content license	Creative Commons Attribution/
# Share-Alike 4.0 (most text also dual-licensed under GFDL)
#
#   Launched        VERB       ROOT       --> Launched
#   	               SPACE      dep        --> Launched
#   15              NUM        nummod     --> January
#   January         PROPN      npadvmod   --> Launched
#   2001            NUM        nummod     --> January
#   ;               PUNCT      punct      --> Launched
#   24              NUM        nummod     --> years
#   years           NOUN       npadvmod   --> ago
#   ago             ADP        advmod     --> Alike
#
#                SPACE      dep        --> ago
#   Content         ADJ        amod       --> license
#   license         NOUN       compound   --> Alike
#   	               SPACE      dep        --> license
#   Creative        PROPN      compound   --> Attribution/
#   Commons         PROPN      compound   --> Attribution/
#   Attribution/    PROPN      compound   --> Alike
#
#                SPACE      dep        --> Attribution/
#   Share           PROPN      compound   --> Alike
#   -               PUNCT      punct      --> Alike
#   Alike           PROPN      npadvmod   --> Launched
#   4.0             NUM        appos      --> Alike
#   (               PUNCT      punct      --> text
#   most            ADJ        amod       --> text
#   text            NOUN       appos      --> Alike
#   also            ADV        advmod     --> licensed
#   dual            ADV        advmod     --> licensed
#   -               PUNCT      punct      --> licensed
#   licensed        VERB       relcl      --> text
#   under           ADP        prep       --> licensed
#   GFDL            PROPN      pobj       --> under
#   )               PUNCT      punct      --> text
#
#                SPACE      dep        --> )
#
# Sentence: Media licensing varies
# Written in	PHP
# The English Wikipedia is the primary[a] English-language edition of Wikipedia, an online encyclopedia.
#   Media           NOUN       nsubj      --> varies
#   licensing       NOUN       acl        --> Media
#   varies          AUX        aux        --> Written
#
#                SPACE      dep        --> varies
#   Written         VERB       csubj      --> is
#   in              ADP        prep       --> Written
#   	               SPACE      dep        --> in
#   PHP             PROPN      nmod       --> Wikipedia
#
#                SPACE      dep        --> PHP
#   The             DET        det        --> Wikipedia
#   English         PROPN      compound   --> Wikipedia
#   Wikipedia       PROPN      pobj       --> in
#   is              AUX        ROOT       --> is
#   the             DET        det        --> edition
#   primary[a       NOUN       amod       --> edition
#   ]               X          punct      --> edition
#   English         ADJ        amod       --> language
#   -               PUNCT      punct      --> language
#   language        NOUN       compound   --> edition
#   edition         NOUN       attr       --> is
#   of              ADP        prep       --> edition
#   Wikipedia       PROPN      pobj       --> of
#   ,               PUNCT      punct      --> Wikipedia
#   an              DET        det        --> encyclopedia
#   online          ADJ        amod       --> encyclopedia
#   encyclopedia    NOUN       appos      --> Wikipedia
#   .               PUNCT      punct      --> is
#
# Sentence: It was created by Jimmy Wales and Larry Sanger on 15 January 2001, as Wikipedia's first edition.
#
#
#   It              PRON       nsubjpass  --> created
#   was             AUX        auxpass    --> created
#   created         VERB       ROOT       --> created
#   by              ADP        agent      --> created
#   Jimmy           PROPN      compound   --> Wales
#   Wales           PROPN      pobj       --> by
#   and             CCONJ      cc         --> Wales
#   Larry           PROPN      compound   --> Sanger
#   Sanger          PROPN      conj       --> Wales
#   on              ADP        prep       --> created
#   15              NUM        nummod     --> January
#   January         PROPN      pobj       --> on
#   2001            NUM        nummod     --> January
#   ,               PUNCT      punct      --> January
#   as              ADP        prep       --> created
#   Wikipedia       PROPN      poss       --> edition
#   's              PART       case       --> Wikipedia
#   first           ADJ        amod       --> edition
#   edition         NOUN       pobj       --> as
#   .               PUNCT      punct      --> created
#
#
#               SPACE      dep        --> .
#
# Sentence: English Wikipedia is hosted alongside other language editions by the Wikimedia Foundation, an American nonprofit organization.
#   English         PROPN      compound   --> Wikipedia
#   Wikipedia       PROPN      nsubjpass  --> hosted
#   is              AUX        auxpass    --> hosted
#   hosted          VERB       ROOT       --> hosted
#   alongside       ADP        prep       --> hosted
#   other           ADJ        amod       --> editions
#   language        NOUN       compound   --> editions
#   editions        NOUN       pobj       --> alongside
#   by              ADP        agent      --> hosted
#   the             DET        det        --> Foundation
#   Wikimedia       PROPN      compound   --> Foundation
#   Foundation      PROPN      pobj       --> by
#   ,               PUNCT      punct      --> Foundation
#   an              DET        det        --> organization
#   American        ADJ        amod       --> organization
#   nonprofit       ADJ        amod       --> organization
#   organization    NOUN       appos      --> Foundation
#   .               PUNCT      punct      --> hosted
#
# Sentence: Its content, written independently of other editions by volunteer editors known as Wikipedians,[1] is in various varieties of English while aiming to stay consistent within articles.
#   Its             PRON       poss       --> content
#   content         NOUN       nsubj      --> is
#   ,               PUNCT      punct      --> content
#   written         VERB       acl        --> content
#   independently   ADV        advmod     --> written
#   of              ADP        prep       --> written
#   other           ADJ        amod       --> editions
#   editions        NOUN       pobj       --> of
#   by              ADP        prep       --> editions
#   volunteer       NOUN       compound   --> editors
#   editors         NOUN       pobj       --> by
#   known           VERB       acl        --> editors
#   as              ADP        prep       --> known
#   Wikipedians,[1  PROPN      pobj       --> as
#   ]               PUNCT      appos      --> content
#   is              AUX        ROOT       --> is
#   in              ADP        prep       --> is
#   various         ADJ        amod       --> varieties
#   varieties       NOUN       pobj       --> in
#   of              ADP        prep       --> varieties
#   English         PROPN      pobj       --> of
#   while           SCONJ      mark       --> aiming
#   aiming          VERB       advcl      --> is
#   to              PART       aux        --> stay
#   stay            VERB       xcomp      --> aiming
#   consistent      ADJ        acomp      --> stay
#   within          ADP        prep       --> stay
#   articles        NOUN       pobj       --> within
#   .               PUNCT      punct      --> is
#
# Sentence: Its internal newspaper is The Signpost.
#
#
#   Its             PRON       poss       --> newspaper
#   internal        ADJ        amod       --> newspaper
#   newspaper       NOUN       nsubj      --> is
#   is              AUX        ROOT       --> is
#   The             DET        det        --> Signpost
#   Signpost        PROPN      attr       --> is
#   .               PUNCT      punct      --> is
#
#
#               SPACE      dep        --> .
#
# Sentence: English Wikipedia is the most read version of Wikipedia,[2][3] accounting for 48% of Wikipedia's cumulative traffic, with the remaining percentage split among the other languages.[4] The English Wikipedia has the most articles of any edition, at 7,107,928 as of December 2025.[b]
#   English         PROPN      compound   --> Wikipedia
#   Wikipedia       PROPN      nsubj      --> is
#   is              AUX        ccomp      --> has
#   the             DET        det        --> version
#   most            ADV        advmod     --> read
#   read            ADJ        amod       --> version
#   version         NOUN       attr       --> is
#   of              ADP        prep       --> version
#   Wikipedia,[2][3 PROPN      pobj       --> of
#   ]               PUNCT      punct      --> Wikipedia,[2][3
#   accounting      NOUN       pobj       --> of
#   for             ADP        prep       --> accounting
#   48              NUM        nummod     --> %
#   %               NOUN       pobj       --> for
#   of              ADP        prep       --> %
#   Wikipedia       PROPN      poss       --> traffic
#   's              PART       case       --> Wikipedia
#   cumulative      ADJ        amod       --> traffic
#   traffic         NOUN       pobj       --> of
#   ,               PUNCT      punct      --> version
#   with            ADP        prep       --> version
#   the             DET        det        --> split
#   remaining       VERB       amod       --> split
#   percentage      NOUN       compound   --> split
#   split           NOUN       pobj       --> with
#   among           ADP        prep       --> split
#   the             DET        det        --> languages.[4
#   other           ADJ        amod       --> languages.[4
#   languages.[4    NOUN       pobj       --> among
#   ]               PUNCT      punct      --> has
#   The             DET        det        --> Wikipedia
#   English         PROPN      compound   --> Wikipedia
#   Wikipedia       PROPN      nsubj      --> has
#   has             VERB       ROOT       --> has
#   the             DET        det        --> articles
#   most            ADJ        amod       --> articles
#   articles        NOUN       dobj       --> has
#   of              ADP        prep       --> articles
#   any             DET        det        --> edition
#   edition         NOUN       pobj       --> of
#   ,               PUNCT      punct      --> has
#   at              ADP        prep       --> has
#   7,107,928       NUM        pobj       --> at
#   as              ADP        prep       --> 7,107,928
#   of              ADP        prep       --> as
#   December        PROPN      pobj       --> of
#   2025.[b         NUM        nummod     --> December
#   ]               PUNCT      punct      --> has
#
# Sentence: It contains 10.8% of articles in all Wikipedias,[b] although it lacks millions of articles found in other editions.[1]
#   It              PRON       nsubj      --> contains
#   contains        VERB       ROOT       --> contains
#   10.8            NUM        nummod     --> %
#   %               NOUN       dobj       --> contains
#   of              ADP        prep       --> %
#   articles        NOUN       pobj       --> of
#   in              ADP        prep       --> contains
#   all             DET        det        --> Wikipedias,[b
#   Wikipedias,[b   NOUN       pobj       --> in
#   ]               PUNCT      punct      --> contains
#   although        SCONJ      mark       --> lacks
#   it              PRON       nsubj      --> lacks
#   lacks           VERB       advcl      --> contains
#   millions        NOUN       dobj       --> lacks
#   of              ADP        prep       --> millions
#   articles        NOUN       pobj       --> of
#   found           VERB       acl        --> articles
#   in              ADP        prep       --> found
#   other           ADJ        amod       --> editions.[1
#   editions.[1     NOUN       pobj       --> in
#   ]               PUNCT      punct      --> contains
#
# Sentence: The edition's one-billionth edit was made on 13 January 2021 by editor Steven Pruitt.[5]
#
# English Wikipedia, often as a stand-in for Wikipedia overall, has been praised for its enablement of the democratization of knowledge, extent of coverage, unique structure, culture, and reduced degree of commercial bias.
#   The             DET        det        --> edition
#   edition         NOUN       poss       --> edit
#   's              PART       case       --> edition
#   one             NUM        nummod     --> billionth
#   -               PUNCT      punct      --> billionth
#   billionth       NOUN       compound   --> edit
#   edit            NOUN       nsubjpass  --> made
#   was             AUX        auxpass    --> made
#   made            VERB       ccomp      --> praised
#   on              ADP        prep       --> made
#   13              NUM        nummod     --> January
#   January         PROPN      pobj       --> on
#   2021            NUM        nummod     --> January
#   by              ADP        agent      --> made
#   editor          NOUN       compound   --> Wikipedia
#   Steven          PROPN      compound   --> Pruitt.[5
#   Pruitt.[5       PROPN      nmod       --> Wikipedia
#   ]               PUNCT      punct      --> Pruitt.[5
#
#
#               SPACE      dep        --> ]
#   English         PROPN      compound   --> Wikipedia
#   Wikipedia       PROPN      pobj       --> by
#   ,               PUNCT      punct      --> made
#   often           ADV        advmod     --> as
#   as              ADP        prep       --> made
#   a               DET        det        --> in
#   stand           NOUN       compound   --> in
#   -               PUNCT      punct      --> in
#   in              NOUN       pobj       --> as
#   for             ADP        prep       --> in
#   Wikipedia       PROPN      pobj       --> for
#   overall         ADV        amod       --> as
#   ,               PUNCT      punct      --> made
#   has             AUX        aux        --> praised
#   been            AUX        auxpass    --> praised
#   praised         VERB       ROOT       --> praised
#   for             ADP        prep       --> praised
#   its             PRON       poss       --> enablement
#   enablement      NOUN       pobj       --> for
#   of              ADP        prep       --> enablement
#   the             DET        det        --> democratization
#   democratization NOUN       pobj       --> of
#   of              ADP        prep       --> democratization
#   knowledge       NOUN       pobj       --> of
#   ,               PUNCT      punct      --> enablement
#   extent          NOUN       appos      --> enablement
#   of              ADP        prep       --> extent
#   coverage        NOUN       pobj       --> of
#   ,               PUNCT      punct      --> extent
#   unique          ADJ        amod       --> structure
#   structure       NOUN       conj       --> extent
#   ,               PUNCT      punct      --> structure
#   culture         NOUN       conj       --> structure
#   ,               PUNCT      punct      --> culture
#   and             CCONJ      cc         --> culture
#   reduced         VERB       amod       --> degree
#   degree          NOUN       conj       --> culture
#   of              ADP        prep       --> degree
#   commercial      ADJ        amod       --> bias
#   bias            NOUN       pobj       --> of
#   .               PUNCT      punct      --> praised
#
# Sentence: It has been criticized for exhibiting systemic bias, particularly gender bias against women and ideological bias.[6][7]
#   It              PRON       nsubjpass  --> criticized
#   has             AUX        aux        --> criticized
#   been            AUX        auxpass    --> criticized
#   criticized      VERB       ROOT       --> criticized
#   for             ADP        prep       --> criticized
#   exhibiting      VERB       pcomp      --> for
#   systemic        ADJ        amod       --> bias
#   bias            NOUN       dobj       --> exhibiting
#   ,               PUNCT      punct      --> bias
#   particularly    ADV        advmod     --> bias
#   gender          NOUN       compound   --> bias
#   bias            NOUN       appos      --> bias
#   against         ADP        prep       --> bias
#   women           NOUN       pobj       --> against
#   and             CCONJ      cc         --> women
#   ideological     ADJ        amod       --> bias.[6][7
#   bias.[6][7      PROPN      conj       --> women
#   ]               PUNCT      punct      --> criticized
#
# Sentence: While its reliability was frequently criticized in the 2000s, it has improved over time, receiving greater praise in the late 2010s and throughout the 2020s,[8][6][9][c] having become an important fact-checking site.[10][11] English Wikipedia has been characterized as having less cultural bias than other language editions due to its broader editor base.[2]
#
# Articles
#
# Screenshot of Wikipedia's article on Earth, 18 January 2023
# Opening English Wikipedia's main page with Mozilla Firefox 99 on Ubuntu 20.04
#
#   While           SCONJ      mark       --> criticized
#   its             PRON       poss       --> reliability
#   reliability     NOUN       nsubjpass  --> criticized
#   was             AUX        auxpass    --> criticized
#   frequently      ADV        advmod     --> criticized
#   criticized      VERB       advcl      --> improved
#   in              ADP        prep       --> criticized
#   the             DET        det        --> 2000s
#   2000s           NOUN       pobj       --> in
#   ,               PUNCT      punct      --> improved
#   it              PRON       nsubj      --> improved
#   has             AUX        aux        --> improved
#   improved        VERB       ccomp      --> characterized
#   over            ADP        prep       --> improved
#   time            NOUN       pobj       --> over
#   ,               PUNCT      punct      --> improved
#   receiving       VERB       advcl      --> improved
#   greater         ADJ        amod       --> praise
#   praise          NOUN       dobj       --> receiving
#   in              ADP        prep       --> receiving
#   the             DET        det        --> 2010s
#   late            ADJ        amod       --> 2010s
#   2010s           NOUN       pobj       --> in
#   and             CCONJ      cc         --> in
#   throughout      ADP        conj       --> in
#   the             DET        det        --> 2020s,[8][6][9][c
#   2020s,[8][6][9][c NUM        pobj       --> throughout
#   ]               PUNCT      punct      --> receiving
#   having          AUX        aux        --> become
#   become          VERB       advcl      --> receiving
#   an              DET        det        --> site.[10][11
#   important       ADJ        amod       --> site.[10][11
#   fact            NOUN       npadvmod   --> checking
#   -               PUNCT      punct      --> checking
#   checking        VERB       amod       --> site.[10][11
#   site.[10][11    NOUN       attr       --> become
#   ]               PUNCT      punct      --> characterized
#   English         PROPN      compound   --> Wikipedia
#   Wikipedia       PROPN      nsubjpass  --> characterized
#   has             AUX        aux        --> characterized
#   been            AUX        auxpass    --> characterized
#   characterized   VERB       ROOT       --> characterized
#   as              ADP        prep       --> characterized
#   having          VERB       pcomp      --> as
#   less            ADJ        amod       --> bias
#   cultural        ADJ        amod       --> bias
#   bias            NOUN       dobj       --> having
#   than            ADP        prep       --> bias
#   other           ADJ        amod       --> editions
#   language        NOUN       compound   --> editions
#   editions        NOUN       pobj       --> than
#   due             ADP        prep       --> having
#   to              ADP        pcomp      --> due
#   its             PRON       poss       --> editor
#   broader         ADJ        amod       --> editor
#   editor          NOUN       pobj       --> due
#   base.[2         ADV        appos      --> editor
#   ]               PUNCT      punct      --> editor
#
#
#               SPACE      dep        --> ]
#   Articles        PROPN      compound   --> Screenshot
#
#
#               SPACE      dep        --> Articles
#   Screenshot      PROPN      appos      --> editor
#   of              ADP        prep       --> Screenshot
#   Wikipedia       PROPN      poss       --> article
#   's              PART       case       --> Wikipedia
#   article         NOUN       pobj       --> of
#   on              ADP        prep       --> article
#   Earth           PROPN      pobj       --> on
#   ,               PUNCT      punct      --> Screenshot
#   18              NUM        nummod     --> January
#   January         PROPN      nmod       --> page
#   2023            NUM        nummod     --> January
#
#                SPACE      dep        --> 2023
#   Opening         PROPN      compound   --> Wikipedia
#   English         PROPN      compound   --> Wikipedia
#   Wikipedia       PROPN      poss       --> page
#   's              PART       case       --> Wikipedia
#   main            ADJ        amod       --> page
#   page            NOUN       dobj       --> having
#   with            ADP        prep       --> page
#   Mozilla         PROPN      compound   --> Firefox
#   Firefox         PROPN      pobj       --> with
#   99              NUM        nummod     --> Firefox
#   on              ADP        prep       --> page
#   Ubuntu          PROPN      pobj       --> on
#   20.04           NUM        nummod     --> Ubuntu
#
#                SPACE      dep        --> 20.04
#
# Sentence: The English Wikipedia surpassed seven million articles on 28 May 2025.[12]
#   The             DET        det        --> Wikipedia
#   English         PROPN      compound   --> Wikipedia
#   Wikipedia       PROPN      nsubj      --> surpassed
#   surpassed       VERB       ROOT       --> surpassed
#   seven           NUM        compound   --> million
#   million         NUM        nummod     --> articles
#   articles        NOUN       dobj       --> surpassed
#   on              ADP        prep       --> surpassed
#   28              NUM        nummod     --> 2025.[12
#   May             PROPN      compound   --> 2025.[12
#   2025.[12        NUM        pobj       --> on
#   ]               PUNCT      punct      --> surpassed
#
# Sentence: In November 2022, the total volume of the compressed texts of its articles amounted to 20 gigabytes.[13]
#
# The edition's one-billionth edit was made on 13 January 2021 by Ser Amantio di Nicolao (Steven Pruitt) who as of that date is the user with the highest number of edits on the English Wikipedia, at over four million.[5]
#   In              ADP        prep       --> amounted
#   November        PROPN      pobj       --> In
#   2022            NUM        nummod     --> November
#   ,               PUNCT      punct      --> amounted
#   the             DET        det        --> volume
#   total           ADJ        amod       --> volume
#   volume          NOUN       nsubj      --> amounted
#   of              ADP        prep       --> volume
#   the             DET        det        --> texts
#   compressed      ADJ        amod       --> texts
#   texts           NOUN       pobj       --> of
#   of              ADP        prep       --> texts
#   its             PRON       poss       --> articles
#   articles        NOUN       pobj       --> of
#   amounted        VERB       ROOT       --> amounted
#   to              ADP        prep       --> amounted
#   20              NUM        nummod     --> gigabytes.[13
#   gigabytes.[13   NOUN       pobj       --> to
#   ]               PUNCT      punct      --> gigabytes.[13
#
#
#               SPACE      dep        --> ]
#   The             DET        det        --> edition
#   edition         NOUN       poss       --> edit
#   's              PART       case       --> edition
#   one             NUM        nummod     --> billionth
#   -               PUNCT      punct      --> billionth
#   billionth       NOUN       compound   --> edit
#   edit            NOUN       nsubjpass  --> made
#   was             AUX        auxpass    --> made
#   made            VERB       conj       --> amounted
#   on              ADP        prep       --> made
#   13              NUM        nummod     --> January
#   January         PROPN      pobj       --> on
#   2021            NUM        nummod     --> January
#   by              ADP        agent      --> made
#   Ser             PROPN      compound   --> Amantio
#   Amantio         PROPN      nmod       --> Nicolao
#   di              X          nmod       --> Nicolao
#   Nicolao         PROPN      pobj       --> by
#   (               PUNCT      punct      --> Pruitt
#   Steven          PROPN      compound   --> Pruitt
#   Pruitt          PROPN      appos      --> Nicolao
#   )               PUNCT      punct      --> Pruitt
#   who             PRON       nsubj      --> is
#   as              ADP        prep       --> is
#   of              ADP        prep       --> as
#   that            DET        det        --> date
#   date            NOUN       pobj       --> of
#   is              AUX        relcl      --> Nicolao
#   the             DET        det        --> user
#   user            NOUN       attr       --> is
#   with            ADP        prep       --> user
#   the             DET        det        --> number
#   highest         ADJ        amod       --> number
#   number          NOUN       pobj       --> with
#   of              ADP        prep       --> number
#   edits           NOUN       pobj       --> of
#   on              ADP        prep       --> edits
#   the             DET        det        --> Wikipedia
#   English         PROPN      compound   --> Wikipedia
#   Wikipedia       PROPN      pobj       --> on
#   ,               PUNCT      punct      --> Nicolao
#   at              ADP        prep       --> made
#   over            ADP        quantmod   --> four
#   four            NUM        nummod     --> million.[5
#   million.[5      NOUN       pobj       --> at
#   ]               PUNCT      punct      --> made
#
# Sentence: Currently, there are 7,107,928 articles created with 955,102 files.
#   Currently       ADV        advmod     --> are
#   ,               PUNCT      punct      --> are
#   there           PRON       expl       --> are
#   are             VERB       ROOT       --> are
#   7,107,928       NUM        nummod     --> articles
#   articles        NOUN       attr       --> are
#   created         VERB       acl        --> articles
#   with            ADP        prep       --> created
#   955,102         NUM        nummod     --> files
#   files           NOUN       pobj       --> with
#   .               PUNCT      punct      --> are
#
# Sentence: The encyclopedia is home to 10.8% of articles in all Wikipedias (down from more than 50% in 2003).[14][15]
#   The             DET        det        --> encyclopedia
#   encyclopedia    NOUN       nsubj      --> is
#   is              AUX        ROOT       --> is
#   home            ADV        advmod     --> is
#   to              ADP        prep       --> home
#   10.8            NUM        nummod     --> %
#   %               NOUN       pobj       --> to
#   of              ADP        prep       --> %
#   articles        NOUN       pobj       --> of
#   in              ADP        prep       --> articles
#   all             DET        det        --> Wikipedias
#   Wikipedias      NOUN       pobj       --> in
#   (               PUNCT      punct      --> is
#   down            ADV        advmod     --> is
#   from            ADP        prep       --> down
#   more            ADJ        amod       --> 50
#   than            ADP        quantmod   --> 50
#   50              NUM        nummod     --> %
#   %               NOUN       pobj       --> from
#   in              ADP        prep       --> from
#   2003).[14][15   NUM        pobj       --> in
#   ]               PUNCT      punct      --> is
#
# Sentence: The English Wikipedia currently has 50,685,466 registered accounts of which 830 are administrators.
#
#
#   The             DET        det        --> Wikipedia
#   English         PROPN      compound   --> Wikipedia
#   Wikipedia       PROPN      nsubj      --> has
#   currently       ADV        advmod     --> has
#   has             VERB       ROOT       --> has
#   50,685,466      NUM        nummod     --> accounts
#   registered      VERB       amod       --> accounts
#   accounts        NOUN       dobj       --> has
#   of              ADP        prep       --> are
#   which           PRON       pobj       --> of
#   830             NUM        nsubj      --> are
#   are             AUX        relcl      --> accounts
#   administrators  NOUN       attr       --> are
#   .               PUNCT      punct      --> has
#
#
#               SPACE      dep        --> .
#
# Sentence: Bureaucracy
# Editors of the English Wikipedia have pioneered some ideas as conventions, policies or features which were later adopted by Wikipedia editions in some of the other languages.
#   Bureaucracy     PROPN      compound   --> Editors
#
#                SPACE      dep        --> Bureaucracy
#   Editors         NOUN       nsubj      --> pioneered
#   of              ADP        prep       --> Editors
#   the             DET        det        --> Wikipedia
#   English         PROPN      compound   --> Wikipedia
#   Wikipedia       PROPN      pobj       --> of
#   have            AUX        aux        --> pioneered
#   pioneered       VERB       ROOT       --> pioneered
#   some            DET        det        --> ideas
#   ideas           NOUN       dobj       --> pioneered
#   as              ADP        prep       --> ideas
#   conventions     NOUN       pobj       --> as
#   ,               PUNCT      punct      --> conventions
#   policies        NOUN       conj       --> conventions
#   or              CCONJ      cc         --> policies
#   features        NOUN       conj       --> policies
#   which           PRON       nsubjpass  --> adopted
#   were            AUX        auxpass    --> adopted
#   later           ADV        advmod     --> adopted
#   adopted         VERB       relcl      --> policies
#   by              ADP        agent      --> adopted
#   Wikipedia       PROPN      compound   --> editions
#   editions        NOUN       pobj       --> by
#   in              ADP        prep       --> adopted
#   some            PRON       pobj       --> in
#   of              ADP        prep       --> some
#   the             DET        det        --> languages
#   other           ADJ        amod       --> languages
#   languages       NOUN       pobj       --> of
#   .               PUNCT      punct      --> pioneered
#
# Sentence: These ideas include "featured articles",[16] the neutral-point-of-view policy,[17] navigation templates,[18] the sorting of short "stub" articles into sub-categories,[19] dispute resolution mechanisms such as mediation and arbitration,[20] and weekly collaborations.[21]
#
# Wikipedians
# Main article: Wikipedian
#
# The countries in which the English Wikipedia is the most popular language version of Wikipedia are shown in red.
#
#
#   These           DET        det        --> ideas
#   ideas           NOUN       nsubj      --> include
#   include         VERB       ROOT       --> include
#   "               PUNCT      punct      --> articles",[16
#   featured        VERB       amod       --> articles",[16
#   articles",[16   PROPN      dobj       --> include
#   ]               PUNCT      punct      --> include
#   the             DET        det        --> navigation
#   neutral         ADJ        amod       --> point
#   -               PUNCT      punct      --> point
#   point           NOUN       nmod       --> policy,[17
#   -               PUNCT      punct      --> point
#   of              ADP        prep       --> point
#   -               PUNCT      punct      --> of
#   view            NOUN       pobj       --> of
#   policy,[17      X          nmod       --> navigation
#   ]               PUNCT      punct      --> policy,[17
#   navigation      NOUN       dobj       --> include
#   templates,[18   NUM        appos      --> navigation
#   ]               PUNCT      punct      --> navigation
#   the             DET        det        --> sorting
#   sorting         NOUN       appos      --> navigation
#   of              ADP        prep       --> sorting
#   short           ADJ        amod       --> articles
#   "               PUNCT      punct      --> articles
#   stub            ADJ        nmod       --> articles
#   "               PUNCT      punct      --> articles
#   articles        NOUN       pobj       --> of
#   into            ADP        prep       --> sorting
#   sub             NOUN       nmod       --> mechanisms
#   -               NOUN       punct      --> sub
#   categories,[19  NUM        nummod     --> dispute
#   ]               PUNCT      punct      --> dispute
#   dispute         NOUN       compound   --> resolution
#   resolution      NOUN       compound   --> mechanisms
#   mechanisms      NOUN       pobj       --> into
#   such            ADJ        amod       --> as
#   as              ADP        prep       --> mechanisms
#   mediation       NOUN       pobj       --> as
#   and             CCONJ      cc         --> mediation
#   arbitration,[20 NUM        conj       --> mediation
#   ]               PUNCT      punct      --> sorting
#   and             CCONJ      cc         --> sorting
#   weekly          ADJ        amod       --> article
#   collaborations.[21 PROPN      nmod       --> article
#   ]               PUNCT      punct      --> collaborations.[21
#
#
#               SPACE      dep        --> ]
#   Wikipedians     PROPN      amod       --> article
#
#                SPACE      dep        --> Wikipedians
#   Main            ADJ        amod       --> article
#   article         NOUN       conj       --> sorting
#   :               PUNCT      punct      --> include
#   Wikipedian      PROPN      compound   --> countries
#
#
#               SPACE      dep        --> Wikipedian
#   The             DET        det        --> countries
#   countries       NOUN       nsubjpass  --> shown
#   in              ADP        prep       --> is
#   which           PRON       pobj       --> in
#   the             DET        det        --> Wikipedia
#   English         PROPN      compound   --> Wikipedia
#   Wikipedia       PROPN      nsubj      --> is
#   is              AUX        relcl      --> countries
#   the             DET        det        --> version
#   most            ADV        advmod     --> popular
#   popular         ADJ        amod       --> version
#   language        NOUN       compound   --> version
#   version         NOUN       attr       --> is
#   of              ADP        prep       --> version
#   Wikipedia       PROPN      pobj       --> of
#   are             AUX        auxpass    --> shown
#   shown           VERB       ccomp      --> include
#   in              ADP        prep       --> shown
#   red             PROPN      pobj       --> in
#   .               PUNCT      punct      --> shown
#
#
#               SPACE      dep        --> .
#
# Sentence: Number of volunteer editors on the English Wikipedia over time
#
# Edits to English Wikipedia by country as of January 2022
#
# The English Wikipedia (marked blue in the graph) is the most-read version of Wikipedia, accounting for 48% of the website's global traffic as of 2021.
#
#
#   Number          NOUN       nsubj      --> is
#   of              ADP        prep       --> Number
#   volunteer       NOUN       compound   --> editors
#   editors         NOUN       pobj       --> of
#   on              ADP        prep       --> Number
#   the             DET        det        --> Wikipedia
#   English         PROPN      compound   --> Wikipedia
#   Wikipedia       PROPN      pobj       --> on
#   over            ADP        prep       --> Number
#   time            NOUN       compound   --> Edits
#
#
#               SPACE      dep        --> time
#   Edits           NOUN       pobj       --> over
#   to              ADP        prep       --> Edits
#   English         PROPN      compound   --> Wikipedia
#   Wikipedia       PROPN      pobj       --> to
#   by              ADP        prep       --> Edits
#   country         NOUN       pobj       --> by
#   as              ADP        prep       --> Number
#   of              ADP        prep       --> as
#   January         PROPN      pobj       --> of
#   2022            NUM        nummod     --> January
#
#
#               SPACE      dep        --> 2022
#   The             DET        det        --> Wikipedia
#   English         PROPN      compound   --> Wikipedia
#   Wikipedia       PROPN      pobj       --> as
#   (               PUNCT      punct      --> marked
#   marked          VERB       parataxis  --> Wikipedia
#   blue            ADJ        dobj       --> marked
#   in              ADP        prep       --> marked
#   the             DET        det        --> graph
#   graph           NOUN       pobj       --> in
#   )               PUNCT      punct      --> marked
#   is              AUX        ROOT       --> is
#   the             DET        det        --> version
#   most            ADV        advmod     --> read
#   -               PUNCT      punct      --> read
#   read            VERB       amod       --> version
#   version         NOUN       attr       --> is
#   of              ADP        prep       --> version
#   Wikipedia       PROPN      pobj       --> of
#   ,               PUNCT      punct      --> is
#   accounting      VERB       advcl      --> is
#   for             ADP        prep       --> accounting
#   48              NUM        nummod     --> %
#   %               NOUN       pobj       --> for
#   of              ADP        prep       --> %
#   the             DET        det        --> website
#   website         NOUN       poss       --> traffic
#   's              PART       case       --> website
#   global          ADJ        amod       --> traffic
#   traffic         NOUN       pobj       --> of
#   as              ADP        prep       --> accounting
#   of              ADP        prep       --> as
#   2021            NUM        pobj       --> of
#   .               PUNCT      punct      --> is
#
#
#               SPACE      dep        --> .
#
# Sentence: The English Wikipedia has consistently been the most edited Wikipedia language version.
#
#   The             DET        det        --> Wikipedia
#   English         PROPN      compound   --> Wikipedia
#   Wikipedia       PROPN      nsubj      --> been
#   has             AUX        aux        --> been
#   consistently    ADV        advmod     --> been
#   been            AUX        ROOT       --> been
#   the             DET        det        --> version
#   most            ADV        advmod     --> edited
#   edited          VERB       amod       --> version
#   Wikipedia       PROPN      compound   --> version
#   language        NOUN       compound   --> version
#   version         NOUN       attr       --> been
#   .               PUNCT      punct      --> been
#
#                SPACE      dep        --> .
#
# Sentence: The English Wikipedia reached 4,000,000 registered user accounts on 1 April 2007,[22] over a year since the millionth Wikipedian registered an account in February 2006.[23]
#
# Over 1,100,000 volunteer editors have edited Wikipedia more than 10 times.[24] Over 30,000 editors perform more than 5 edits per month, and over 3,000 perform more than 100 edits per month.[25]
#
# On 1 March 2014, The Economist, in an article titled "The Future of Wikipedia", cited a trend analysis concerning data published by the Wikimedia Foundation stating that "[t]he number of editors for the English-language version has fallen by a third in seven years.
#   The             DET        det        --> Wikipedia
#   English         PROPN      compound   --> Wikipedia
#   Wikipedia       PROPN      nsubj      --> reached
#   reached         VERB       ROOT       --> reached
#   4,000,000       NUM        nummod     --> user
#   registered      VERB       amod       --> user
#   user            NOUN       compound   --> accounts
#   accounts        VERB       dobj       --> reached
#   on              ADP        prep       --> accounts
#   1               NUM        nummod     --> April
#   April           PROPN      pobj       --> on
#   2007,[22        NUM        nummod     --> April
#   ]               PUNCT      punct      --> accounts
#   over            ADP        prep       --> reached
#   a               DET        det        --> year
#   year            NOUN       pobj       --> over
#   since           SCONJ      mark       --> registered
#   the             DET        det        --> millionth
#   millionth       ADJ        pobj       --> since
#   Wikipedian      PROPN      nsubj      --> registered
#   registered      VERB       advcl      --> reached
#   an              DET        det        --> account
#   account         NOUN       dobj       --> registered
#   in              ADP        prep       --> registered
#   February        PROPN      pobj       --> in
#   2006.[23        PROPN      nummod     --> February
#   ]               PUNCT      punct      --> February
#
#
#               SPACE      dep        --> ]
#   Over            ADP        quantmod   --> 1,100,000
#   1,100,000       NUM        nummod     --> editors
#   volunteer       NOUN       compound   --> editors
#   editors         NOUN       nsubj      --> edited
#   have            AUX        aux        --> edited
#   edited          VERB       conj       --> registered
#   Wikipedia       PROPN      dobj       --> edited
#   more            ADJ        amod       --> 10
#   than            ADP        quantmod   --> 10
#   10              NUM        nummod     --> times.[24
#   times.[24       NOUN       appos      --> Wikipedia
#   ]               PUNCT      dep        --> perform
#   Over            ADP        quantmod   --> 30,000
#   30,000          NUM        nummod     --> editors
#   editors         NOUN       nsubj      --> perform
#   perform         VERB       ccomp      --> edited
#   more            ADJ        amod       --> 5
#   than            ADP        quantmod   --> 5
#   5               NUM        nummod     --> edits
#   edits           NOUN       dobj       --> perform
#   per             ADP        prep       --> edits
#   month           NOUN       pobj       --> per
#   ,               PUNCT      punct      --> perform
#   and             CCONJ      cc         --> perform
# ...
#   process         NOUN       nsubj      --> is
#   is              AUX        ccomp      --> concluded
#   ineffective     ADJ        acomp      --> is
#   in              ADP        prep       --> ineffective
#   assessing       VERB       pcomp      --> in
#   the             DET        det        --> quality
#   quality         NOUN       dobj       --> assessing
#   of              ADP        prep       --> quality
#   articles.[47    PROPN      pobj       --> of
#   ]               X          punct      --> of
#
#
#               SPACE      dep        --> ]
#   Internal        PROPN      amod       --> news
#   news            NOUN       compound   --> publications
#   publications    NOUN       pobj       --> of
#
#
#               SPACE      dep        --> publications
#   The             DET        det        --> icon
#   Signpost        PROPN      compound   --> icon
#   icon            NOUN       pobj       --> of
#   ,               PUNCT      punct      --> assessing
#   showing         VERB       advcl      --> assessing
#   a               DET        det        --> publications
#   styled          VERB       amod       --> publications
#   'S              PROPN      nmod       --> publications
#   '               CCONJ      punct      --> publications
#
#                SPACE      dep        --> '
#   Community       NOUN       npadvmod   --> produced
#   -               PUNCT      punct      --> produced
#   produced        VERB       amod       --> publications
#   news            NOUN       compound   --> publications
#   publications    NOUN       nsubj      --> include
#   include         VERB       ccomp      --> showing
#   The             DET        det        --> Signpost.[48
#   Signpost.[48    PROPN      dobj       --> include
#   ]               X          punct      --> Signpost.[48
#   Other           ADJ        amod       --> publications
#   community       NOUN       compound   --> publications
#   news            NOUN       compound   --> publications
#   publications    NOUN       nsubj      --> include
#   include         VERB       relcl      --> Signpost.[48
#   the             DET        det        --> comic
#   "               PUNCT      punct      --> comic
#   WikiWorld       PROPN      nmod       --> web
#   "               PUNCT      punct      --> web
#   web             NOUN       compound   --> comic
#   comic           NOUN       dobj       --> include
#   ,               PUNCT      punct      --> comic
#   the             DET        det        --> podcast
#   Wikipedia       PROPN      compound   --> podcast
#   Weekly          PROPN      compound   --> podcast
#   podcast         NOUN       conj       --> comic
#   ,               PUNCT      punct      --> comic
#   and             CCONJ      cc         --> comic
#   newsletters     NOUN       conj       --> comic
#   of              ADP        prep       --> newsletters
#   specific        ADJ        amod       --> WikiProjects
#   WikiProjects    PROPN      pobj       --> of
#   like            ADP        prep       --> WikiProjects
#   The             DET        det        --> Bugle
#   Bugle           PROPN      pobj       --> like
#   from            ADP        prep       --> Bugle
#   WikiProject     PROPN      compound   --> History
#   Military        PROPN      compound   --> History
#   History         PROPN      pobj       --> from
#   and             CCONJ      cc         --> History
#   the             DET        det        --> newsletter
#   monthly         ADJ        amod       --> newsletter
#   newsletter      NOUN       conj       --> History
#   from            ADP        prep       --> newsletter
#   The             DET        det        --> Guild
#   Guild           PROPN      pobj       --> from
#   of              ADP        prep       --> Guild
#   Copy            PROPN      compound   --> Editors
#   Editors         NOUN       pobj       --> of
#   .               PUNCT      punct      --> appears
#
# Sentence: There are a number of publications from the Wikimedia Foundation and multilingual publications such as the Wikimedia Blog and This Month in Education.
#
#
#   There           PRON       expl       --> are
#   are             VERB       ROOT       --> are
#   a               DET        det        --> number
#   number          NOUN       attr       --> are
#   of              ADP        prep       --> number
#   publications    NOUN       pobj       --> of
#   from            ADP        prep       --> publications
#   the             DET        det        --> Foundation
#   Wikimedia       PROPN      compound   --> Foundation
#   Foundation      PROPN      pobj       --> from
#   and             CCONJ      cc         --> Foundation
#   multilingual    ADJ        amod       --> publications
#   publications    NOUN       conj       --> Foundation
#   such            ADJ        amod       --> as
#   as              ADP        prep       --> publications
#   the             DET        det        --> Blog
#   Wikimedia       PROPN      compound   --> Blog
#   Blog            PROPN      pobj       --> as
#   and             CCONJ      cc         --> Blog
#   This            DET        det        --> Month
#   Month           NOUN       conj       --> Blog
#   in              ADP        prep       --> Month
#   Education       PROPN      pobj       --> in
#   .               PUNCT      punct      --> are
#
#
#               SPACE      dep        --> .
#
# Sentence: See also
#
# Wikipedia page views by language
# English Wikipedia blackout
# Deletionpedia
# Notes
#  The other edition is Simple English Wikipedia, which uses Basic English.
#
#   See             VERB       advcl      --> is
#   also            ADV        advmod     --> views
#
#
#               SPACE      dep        --> also
#   Wikipedia       PROPN      compound   --> page
#   page            NOUN       compound   --> views
#   views           NOUN       dobj       --> See
#   by              ADP        prep       --> views
#   language        NOUN       compound   --> Notes
#
#                SPACE      dep        --> language
#   English         PROPN      compound   --> Wikipedia
#   Wikipedia       PROPN      compound   --> blackout
#   blackout        PROPN      compound   --> Notes
#
#                SPACE      dep        --> blackout
#   Deletionpedia   PROPN      compound   --> Notes
#
#                SPACE      dep        --> Deletionpedia
#   Notes           NOUN       pobj       --> by
#
#                SPACE      dep        --> Notes
#   The             DET        det        --> edition
#   other           ADJ        amod       --> edition
#   edition         NOUN       nsubj      --> is
#   is              AUX        ROOT       --> is
#   Simple          PROPN      compound   --> Wikipedia
#   English         PROPN      compound   --> Wikipedia
#   Wikipedia       PROPN      attr       --> is
#   ,               PUNCT      punct      --> Wikipedia
#   which           PRON       nsubj      --> uses
#   uses            VERB       relcl      --> Wikipedia
#   Basic           PROPN      compound   --> English
#   English         PROPN      dobj       --> uses
#   .               PUNCT      punct      --> is
#
#                SPACE      dep        --> .
#
# Sentence: The number of articles on the English Wikipedia is shown by the MediaWiki variable {{NUMBEROFARTICLES}}, with all Wikipedias as total {{NUMBEROF|ARTICLES|total}} = 66,118,901.
#
#   The             DET        det        --> number
#   number          NOUN       nsubjpass  --> shown
#   of              ADP        prep       --> number
#   articles        NOUN       pobj       --> of
#   on              ADP        prep       --> articles
#   the             DET        det        --> Wikipedia
#   English         PROPN      compound   --> Wikipedia
#   Wikipedia       PROPN      pobj       --> on
#   is              AUX        auxpass    --> shown
#   shown           VERB       ROOT       --> shown
#   by              ADP        agent      --> shown
#   the             DET        det        --> variable
#   MediaWiki       PROPN      compound   --> variable
#   variable        NOUN       pobj       --> by
#   {               PUNCT      punct      --> variable
#   {               PUNCT      punct      --> variable
#   NUMBEROFARTICLES NOUN       appos      --> variable
#   }               PUNCT      punct      --> variable
#   }               PUNCT      punct      --> shown
#   ,               PUNCT      punct      --> shown
#   with            ADP        prep       --> shown
#   all             DET        det        --> Wikipedias
#   Wikipedias      PROPN      pobj       --> with
#   as              ADP        prep       --> Wikipedias
#   total           ADJ        pobj       --> as
#   {               PUNCT      punct      --> NUMBEROF|ARTICLES|total
#   {               PUNCT      punct      --> NUMBEROF|ARTICLES|total
#   NUMBEROF|ARTICLES|total ADJ        appos      --> Wikipedias
#   }               PUNCT      punct      --> Wikipedias
#   }               PUNCT      punct      --> shown
#   =               NUM        prep       --> shown
#   66,118,901      NUM        npadvmod   --> =
#   .               PUNCT      punct      --> shown
#
#                SPACE      dep        --> .
#
# Sentence: Despite this praise, Wikipedia does not recognize itself as a reliable source.
#
#   Despite         SCONJ      prep       --> recognize
#   this            DET        det        --> praise
#   praise          NOUN       pobj       --> Despite
#   ,               PUNCT      punct      --> recognize
#   Wikipedia       PROPN      nsubj      --> recognize
#   does            AUX        aux        --> recognize
#   not             PART       neg        --> recognize
#   recognize       VERB       ROOT       --> recognize
#   itself          PRON       dobj       --> recognize
#   as              ADP        prep       --> recognize
#   a               DET        det        --> source
#   reliable        ADJ        amod       --> source
#   source          NOUN       pobj       --> as
#   .               PUNCT      punct      --> recognize
#
#                SPACE      dep        --> .
#
# Sentence: References
#  Harrison, Stephen (1 September 2021).
#   References      NOUN       compound   --> Harrison
#
#                SPACE      dep        --> References
#   Harrison        PROPN      ROOT       --> Harrison
#   ,               PUNCT      punct      --> Harrison
#   Stephen         PROPN      appos      --> Harrison
#   (               PUNCT      punct      --> Stephen
#   1               NUM        appos      --> Stephen
#   September       PROPN      appos      --> Stephen
#   2021            NUM        nummod     --> September
#   )               PUNCT      punct      --> Stephen
#   .               PUNCT      punct      --> Harrison
#
# Sentence: "Wikipedia Is Trying to Transcend the Limits of Human Language".
#   "               PUNCT      punct      --> Trying
#   Wikipedia       PROPN      nsubj      --> Trying
#   Is              AUX        aux        --> Trying
#   Trying          VERB       ROOT       --> Trying
#   to              PART       aux        --> Transcend
#   Transcend       VERB       xcomp      --> Trying
#   the             DET        det        --> Limits
#   Limits          NOUN       dobj       --> Transcend
#   of              ADP        prep       --> Limits
#   Human           PROPN      compound   --> Language
#   Language        PROPN      pobj       --> of
#   "               PUNCT      punct      --> Transcend
#   .               PUNCT      punct      --> Trying
#
# Sentence: Slate.
#   Slate           NOUN       ROOT       --> Slate
#   .               PUNCT      punct      --> Slate
#
# Sentence: Archived from the original on 30 July 2023.
#   Archived        VERB       ROOT       --> Archived
#   from            ADP        prep       --> Archived
#   the             DET        det        --> original
#   original        NOUN       pobj       --> from
#   on              ADP        prep       --> Archived
#   30              NUM        nummod     --> July
#   July            PROPN      pobj       --> on
#   2023            NUM        nummod     --> July
#   .               PUNCT      punct      --> Archived
#
# Sentence: Retrieved 17 October 2023.
#
#   Retrieved       VERB       ROOT       --> Retrieved
#   17              NUM        dobj       --> Retrieved
#   October         PROPN      npadvmod   --> Retrieved
#   2023            NUM        nummod     --> October
#   .               PUNCT      punct      --> Retrieved
#
#                SPACE      dep        --> .
#
# Sentence: Sato, Yumiko (19 March 2021).
#   Sato            PROPN      ROOT       --> Sato
#   ,               PUNCT      punct      --> Sato
#   Yumiko          PROPN      appos      --> Sato
#   (               PUNCT      punct      --> Yumiko
#   19              NUM        nummod     --> March
#   March           PROPN      npadvmod   --> Yumiko
#   2021            NUM        nummod     --> March
#   )               PUNCT      punct      --> Yumiko
#   .               PUNCT      punct      --> Sato
#
# Sentence: "Non-English Editions of Wikipedia Have a Misinformation Problem".
#   "               PUNCT      punct      --> Have
#   Non             ADJ        compound   --> Editions
#   -               ADJ        amod       --> Editions
#   English         ADJ        amod       --> Editions
#   Editions        PROPN      nsubj      --> Have
#   of              ADP        prep       --> Editions
#   Wikipedia       PROPN      pobj       --> of
#   Have            VERB       ROOT       --> Have
#   a               DET        det        --> Problem
#   Misinformation  PROPN      compound   --> Problem
#   Problem         PROPN      dobj       --> Have
#   "               PUNCT      punct      --> Have
#   .               PUNCT      punct      --> Have
#
# Sentence: Slate.
#   Slate           NOUN       ROOT       --> Slate
#   .               PUNCT      punct      --> Slate
#
# Sentence: Archived from the original on 25 August 2023.
#   Archived        VERB       ROOT       --> Archived
#   from            ADP        prep       --> Archived
#   the             DET        det        --> original
#   original        ADJ        pobj       --> from
#   on              ADP        prep       --> Archived
#   25              NUM        nummod     --> August
#   August          PROPN      pobj       --> on
#   2023            NUM        nummod     --> August
#   .               PUNCT      punct      --> Archived
#
# Sentence: Retrieved 17 October 2023.
#
#   Retrieved       VERB       ROOT       --> Retrieved
#   17              NUM        dobj       --> Retrieved
#   October         PROPN      npadvmod   --> Retrieved
#   2023            NUM        nummod     --> October
#   .               PUNCT      punct      --> Retrieved
#
#                SPACE      dep        --> .
#
# Sentence: Anderson, Monica; Hitlin, Paul; Atkinson, Michelle (14 January 2016).
#   Anderson        PROPN      ROOT       --> Anderson
#   ,               PUNCT      punct      --> Anderson
#   Monica          PROPN      npadvmod   --> Anderson
#   ;               PUNCT      punct      --> Anderson
#   Hitlin          PROPN      conj       --> Anderson
#   ,               PUNCT      punct      --> Hitlin
#   Paul            PROPN      conj       --> Hitlin
#   ;               PUNCT      punct      --> Paul
#   Atkinson        PROPN      conj       --> Paul
#   ,               PUNCT      punct      --> Atkinson
#   Michelle        PROPN      conj       --> Atkinson
#   (               PUNCT      punct      --> Michelle
#   14              NUM        punct      --> Anderson
#   January         PROPN      npadvmod   --> Anderson
#   2016            NUM        nummod     --> January
#   )               PUNCT      punct      --> Anderson
#   .               PUNCT      punct      --> Anderson
#
# Sentence: "Wikipedia at 15: Millions of readers in
#
#   "               PUNCT      punct      --> Wikipedia
#   Wikipedia       PROPN      ROOT       --> Wikipedia
#   at              ADP        prep       --> Wikipedia
#   15              NUM        pobj       --> at
#   :               PUNCT      punct      --> Millions
#   Millions        NOUN       appos      --> Wikipedia
#   of              ADP        prep       --> Millions
#   readers         NOUN       pobj       --> of
#   in              ADP        prep       --> Millions
#
#                SPACE      dep        --> in

# %% [markdown]
# #Visualization

# %%
from spacy import displacy

# %%
displacy.render(doc, style="dep", jupyter=True)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="f6824a7f4187403aa063d102428e2a7a-0" class="displacy" width="352325" height="1012.0" direction="ltr" style="max-width: none; height: 1012.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">
# &quot;</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">en.wikipedia.org&quot;</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">redirects</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">here.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">For</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">main</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="1275">page,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">see</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="1625">Main</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="1800">Page.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="1975">For</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="2325">version</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="2500">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="2675">Wikipedia</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="2850">written</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="3025">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="3200">Basic</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="3375">English,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3375">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="3550">see</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3550">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="3725">Simple</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3725">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="3900">English</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3900">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="4075">Wikipedia.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4075">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="4250">
# </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="4425">Favicon</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4425">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="4600">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4600">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="4775">Wikipedia</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4775">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="4950">English</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4950">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="5125">Wikipedia</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="5125">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="5300">
# </tspan>
#     <tspan c
